# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel("re.xlsx")

# %%
df = data.copy()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
data.info
# Out:
# <bound method DataFrame.info of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
data.ndim
# Out:
# 2

# %%
data_corr = data.corr()
# Out:
# <ipython-input-202-09b271be5fbd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_corr = data.corr()

# %%
data_corr
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.001235    -0.00360
# UnitPrice  -0.001235   1.000000    -0.00456
# CustomerID -0.003600  -0.004560     1.00000

# %%
sns.heatmap(data=data_corr)
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
len(data['Country'].unique())
data['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# CLEANING THE DATA / DATA PREPROCESSING / DATA WRANGLING

# %% [markdown]
# Check for null values and clean them

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# Customer ID

# %%
'''check non-unique value and remove them'''
data.CustomerID.nunique()
# Out:
# 4372

# %%
data[data.CustomerID.isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.InvoiceNo.nunique()
# Out:
# 25900

# %%
data = data[~data.CustomerID.isnull()]
data.shape
# Out:
# (406829, 8)

# %%
# if there are many null values you can drop the column
'''Drop CustomerID column'''
'''data.drop(columns=["CustomerID"],axis=1,inplace=True)'''
# Out:
# 'data.drop(columns=["CustomerID"],axis=1,inplace=True)'

# %%
data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
'''Drop the null rows '''
data = data.dropna()

# %%
'''Here we are checking the unique description items'''
print(data.Description.nunique())
print(data.Description.unique())
# Out:
# 3896
# ['WHITE HANGING HEART T-LIGHT HOLDER' 'WHITE METAL LANTERN'
#  'CREAM CUPID HEARTS COAT HANGER' ... 'PINK CRYSTAL SKULL PHONE CHARM'
#  'CREAM HANGING HEART T-LIGHT HOLDER' 'PAPER CRAFT , LITTLE BIRDIE']

# %%
print(data.Country.unique())
# Out:
# ['United Kingdom' 'France' 'Australia' 'Netherlands' 'Germany' 'Norway'
#  'EIRE' 'Switzerland' 'Spain' 'Poland' 'Portugal' 'Italy' 'Belgium'
#  'Lithuania' 'Japan' 'Iceland' 'Channel Islands' 'Denmark' 'Cyprus'
#  'Sweden' 'Austria' 'Israel' 'Finland' 'Greece' 'Singapore' 'Lebanon'
#  'United Arab Emirates' 'Saudi Arabia' 'Czech Republic' 'Canada'
#  'Unspecified' 'Brazil' 'USA' 'European Community' 'Bahrain' 'Malta' 'RSA']

# %% [markdown]
# Check duplicates

# %%
data.duplicated().sum()
# Out:
# 5225

# %%
data = data[~data.duplicated()]
data.shape
# Out:
# (401604, 8)

# %%
data.shape
# Out:
# (401604, 8)

# %% [markdown]
# Invoice No.

# %%
data[data['InvoiceNo'].str.startswith('C')==True]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# removing all the invoice number who starts with 'C' as they are returned orders
data = data[data['InvoiceNo'].str.startswith('C')!=True]
data.shape
# Out:
# (392732, 8)

# %%
data.InvoiceNo.nunique()
# Out:
# 18536

# %%
data = data[~data.InvoiceNo.isnull()]
data.shape
# Out:
# (392732, 8)

# %% [markdown]
# Stock code

# %%
data.StockCode.nunique()
# Out:
# 3665

# %%
data.StockCode.value_counts().head(10)
# Out:
# 85123A    2023
# 22423     1714
# 85099B    1615
# 84879     1395
# 47566     1390
# 20725     1304
# 22720     1152
# POST      1099
# 23203     1091
# 20727     1078
# Name: StockCode, dtype: int64

# %% [markdown]
# Quantity

# %%
data.Quantity.describe()
# Out:
# count    392732.000000
# mean         13.153718
# std         181.588420
# min           1.000000
# 25%           2.000000
# 50%           6.000000
# 75%          12.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
data = data[data['Quantity']>=0]
data.shape
# Out:
# (392732, 8)

# %% [markdown]
# Description

# %%
'''Check description with question mark and remove them'''
index = data[ (data['Description'] =='?') ].index
data.drop(index , inplace=True)
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data = data[data['Description'].str.islower()!=True]
data.shape
# Out:
# (392732, 8)

# %%
''' Check and delete the rows the description values where first is uppercase other letters are lowercase
for that use istitle()'''

data[data['Description'].str.istitle()==True]['Description'].value_counts()
# Out:
# Manual                   285
# Next Day Carriage         79
# Bank Charges              12
# High Resolution Image      3
# Name: Description, dtype: int64

# %%
data = data[data['Description'].str.istitle()!=True]
data.shape
# Out:
# (392353, 8)

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
column = data['InvoiceNo']

# check if the result is a Series object
print(type(column))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#data = pd.DataFrame(data)
column.to_frame()
# Out:
#        InvoiceNo
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
# ...          ...
# 541904    581587
# 541905    581587
# 541906    581587
# 541907    581587
# 541908    581587
#
# [392353 rows x 1 columns]

# %%
type(column)
# Out:
# pandas.core.series.Series

# %%
print(type(column))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data = data[data['UnitPrice'] !=0.0]
data.shape
# Out:
# (392319, 8)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Correlation - After cleaning

# %%
data_corr = data.corr()
# Out:
# <ipython-input-242-09b271be5fbd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_corr = data.corr()

# %%
data_corr
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.006188   -0.006121
# UnitPrice  -0.006188   1.000000   -0.009520
# CustomerID -0.006121  -0.009520    1.000000

# %%
sns.heatmap(data=data_corr)
# Out:
# <Axes: >

# %% [markdown]
# Insert a column

# %%
data['Amount'] = data['Quantity']*data['UnitPrice']
data['year'] = data['InvoiceDate'].dt.year
data['month'] = data['InvoiceDate'].dt.month
data['day'] = data['InvoiceDate'].dt.day
data['hour'] = data['InvoiceDate'].dt.hour
data['day_of_week'] = data['InvoiceDate'].dt.dayofweek
# Out:
# <ipython-input-245-ab2a96c78e9a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Amount'] = data['Quantity']*data['UnitPrice']
# <ipython-input-245-ab2a96c78e9a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year'] = data['InvoiceDate'].dt.year
# <ipython-input-245-ab2a96c78e9a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Amount  \
# ...

# %%
data_corr = data.corr()
data_corr
# Out:
# <ipython-input-247-8f0c7ef42b26>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_corr = data.corr()
#              Quantity  UnitPrice  CustomerID    Amount      year     month  \
# Quantity     1.000000  -0.006188   -0.006121  0.915865  0.001452 -0.004115
# UnitPrice   -0.006188   1.000000   -0.009520  0.063897 -0.002508 -0.006984
# CustomerID  -0.006121  -0.009520    1.000000 -0.003599 -0.035650  0.029653
# Amount       0.915865   0.063897   -0.003599  1.000000  0.000236 -0.002552
# year         0.001452  -0.002508   -0.035650  0.000236  1.000000 -0.340594
# month       -0.004115  -0.006984    0.029653 -0.002552 -0.340594  1.000000
# day         -0.001159  -0.001311   -0.002651 -0.001966  0.168130 -0.117305
# hour        -0.014689  -0.000713    0.065804 -0.013122 -0.019713  0.058547
# ...

# %%
sns.heatmap(data=data_corr)
# Out:
# <Axes: >

# %% [markdown]
# DATA VISUALISATION

# %%
column = ['InvoiceNo','Amount']

plt.figure(figsize=(15,5))
for i,j in enumerate(column):
    plt.subplot(1,2,i+1)
    sns.barplot(x = data[data['Country']=='United Kingdom'].groupby('Description')[j].nunique().sort_values(ascending=False).head(10).values,
                y = data[data['Country']=='United Kingdom'].groupby('Description')[j].nunique().sort_values(ascending=False).head(10).index,
                color='yellow')
    plt.ylabel('')
    if i==0:
        plt.xlabel('Sum of quantity')
        plt.title('Top 10 products purchased by customers in UK',size=15)
    else:
        plt.xlabel('Total Sales')
        plt.title('Top 10 products with most sales in UK',size=15)
        
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
sns.barplot(y = data[data['Country']=='United Kingdom'].groupby('CustomerID')['Amount'].sum().sort_values(ascending=False).head(10).values,
            x = data[data['Country']=='United Kingdom'].groupby('CustomerID')['Amount'].sum().sort_values(ascending=False).head(10).index, 
            color='green')
plt.ylabel('Sales')
plt.xlabel('Customer IDs')
plt.xticks(rotation=45)
plt.title('Top 10 customers in terms of sales in UK',size=15)

plt.subplot(1,2,2)
sns.barplot(y = data[data['Country']=='United Kingdom'].groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False).head(10).values,
            x = data[data['Country']=='United Kingdom'].groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False).head(10).index, 
            color='green')
plt.ylabel('Number of visits')
plt.xlabel('Customer IDs')
plt.xticks(rotation=45)
plt.title('Top 10 customers in terms of frequency in UK',size=15)

plt.show()

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    if len(colsToPlot) == 1:
        fig, subPlot = plt.subplots(figsize=(40,6))
        subPlot = [subPlot]
    else:
        fig, subPlot = plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(40,6))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar', ax=subPlot[plotNumber])

# %%
'''country_counts = pd.DataFrame(data=data.Country.value_counts())
country_counts =country_counts.reset_index()
country_counts = country_counts.rename(columns={"index":"Country","Country":"Country Counts"})
               CODE'''
#highest_value = pd.DataFrame(data = country_counts["Country"].nlargest(n=5))
#highest_value = highest_value .reset_index()
#highest_value.rename(columns={"index":"Country","Country":"Country Counts"},inplace = True)
# Out:
# 'country_counts = pd.DataFrame(data=data.Country.value_counts())\ncountry_counts =country_counts.reset_index()\ncountry_counts = country_counts.rename(columns={"index":"Country","Country":"Country Counts"})\n               CODE'

# %%
'''country_counts'''
# Out:
# 'country_counts'

# %%
data.hist(['Quantity','InvoiceDate','Amount','month'],figsize=(18,15))
# Out:
# array([[<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'InvoiceDate'}>],
#        [<Axes: title={'center': 'Amount'}>,
#         <Axes: title={'center': 'month'}>]], dtype=object)

# %%
'''DONUT CHART'''

plt.figure(figsize=(25,25))
Country_counts = data.Country.value_counts().nlargest(5)
labels = (np.array(Country_counts.index))
sizes = (np.array(Country_counts/Country_counts.sum())*100)
plt.pie(sizes,labels=labels,shadow=True,startangle=90,autopct='%.2f%%')
  
# draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()

  
# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)
  
# Adding Title of chart
plt.title('Country Counts')

plt.legend(labels, loc = "upper right",title="Country Counts") 
  
# Displaying Chart
plt.show()

# %%
'''data['Country'] = data['Country'].apply(lambda x:'United Kingdom' if x=='United Kingdom' else 'Others')
data.Country.value_counts(normalize=True)'''

#code when u want to change country to uk and others only 2 categories
# Out:
# "data['Country'] = data['Country'].apply(lambda x:'United Kingdom' if x=='United Kingdom' else 'Others')\ndata.Country.value_counts(normalize=True)"

# %%
PlotBarCharts(inpData=data, colsToPlot=['Country'])

# %%
plt.figure(figsize=(50,25))
Country_counts = data.Country.value_counts().nlargest(5)
labels = (np.array(Country_counts.index))
sizes = (np.array(Country_counts/Country_counts.sum())*100)
plt.pie(sizes,labels=labels,shadow=True,startangle=90,autopct='%.2f%%')
plt.legend()
plt.title("Country Percentage")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set_style({'axes.grid' : False})                                            
sns.set_style("darkgrid")
ax = sns.regplot(x=data["Quantity"], y=data["Amount"], marker="+", fit_reg=False)
ax.set_title('Purchases')
ax.set(xlabel='Quantity (units)', ylabel='Total Amount')
plt.show()

# %%
data = data[data["Quantity"] < 20000]

# %%
sns.set_style({'axes.grid' : False})
sns.set_style("darkgrid")
ax = sns.regplot(x=data["Quantity"], y=data["Amount"], marker="+", fit_reg=False)
ax.set_title('Purchases')
ax.set(xlabel='Quantity (units)', ylabel='Total Amount')
plt.show()

# %%
data = data[data["Amount"] < 35000]

# %%
sns.set_style({'axes.grid' : False})
sns.set_style("darkgrid")
ax = sns.regplot(x=data["Quantity"], y=data["Amount"], marker="+", fit_reg=False)
ax.set_title('Purchases')
ax.set(xlabel='Quantity (units)', ylabel='Total Amount')
plt.show()

# %%
plt.figure(figsize=(10,7))

skewness = round(data.Quantity.skew(),2)
kurtosis = round(data.Quantity.kurtosis(),2)
mean = round(np.mean(data.Quantity),0)
median = np.median(data.Quantity)

plt.subplot(2,2,1)
sns.boxplot(y=data.Quantity)
plt.title('Boxplot\n Mean:{}\n Median:{}\n Skewness:{}\n Kurtosis:{}'.format(mean,median,skewness,kurtosis))

plt.subplot(2,2,2)
sns.boxplot(y=data[data.Quantity<5000]['Quantity'])
plt.title('Distribution when Quantity<5000')

plt.subplot(2,2,3)
sns.boxplot(y=data[data.Quantity<200]['Quantity'])
plt.title('Distribution when Quantity<200')

plt.subplot(2,2,4)
sns.boxplot(y=data[data.Quantity<50]['Quantity'])
plt.title('Distribution when Quantity<50')

plt.show()

# %%
data["Quantity"].max()
# Out:
# 4800

# %%
plt.figure(figsize=(12,5))
data[data['Country']=='United Kingdom'].groupby(['year','month'])['Amount'].sum().plot(kind='line',label='UK',color='blue')
data[data['Country']=='Others'].groupby(['year','month'])['Amount'].sum().plot(kind='line',label='Other',color='grey')
plt.xlabel('Year-Month',size=12)
plt.ylabel('Total Sales', size=12)
plt.title('Sales in each month for an year', size=15)
plt.legend(fontsize=12)
plt.show()

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Amount  \
# ...

# %%
# find categorical variables

categorical = [var for var in data.columns if data[var].dtype=='O']
print('There are {} categorical variables\n'.format(len(categorical)))
print('The categorical variables are :', categorical)
# Out:
# There are 4 categorical variables
#
# The categorical variables are : ['InvoiceNo', 'StockCode', 'Description', 'Country']

# %%
data = data[data['Quantity']>0]

# %%
data['Country'].value_counts()
# Out:
# United Kingdom          348864
# Germany                   9016
# France                    8321
# EIRE                      7224
# Spain                     2479
# Netherlands               2359
# Belgium                   2031
# Switzerland               1841
# Portugal                  1446
# Australia                 1181
# Norway                    1068
# Italy                      758
# Channel Islands            746
# Finland                    684
# Cyprus                     602
# Sweden                     449
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     245
# Unspecified                241
# Singapore                  215
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# ...

# %%
print("Number of transactions: ", data['InvoiceNo'].nunique())
print("Number of products bought: ",data['StockCode'].nunique())
print("Number of customers:", data['CustomerID'].nunique() )
print("Percentage of customers NA: ", round(data['CustomerID'].isnull().sum() * 100 / len(data),2),"%" )
# Out:
# Number of transactions:  18451
# Number of products bought:  3660
# Number of customers: 4333
# Percentage of customers NA:  0.0 %

# %% [markdown]
# CUSTOMER RFM (Recency, Frequency, Monetary) ANALYSIS

# %%
monetary = data.groupby('CustomerID')['Amount'].sum()
monetary = monetary.reset_index()
monetary
# Out:
#       CustomerID   Amount
# 0        12347.0  4310.00
# 1        12348.0  1797.24
# 2        12349.0  1757.55
# 3        12350.0   334.40
# 4        12352.0  1665.74
# ...          ...      ...
# 4328     18280.0   180.60
# 4329     18281.0    80.82
# 4330     18282.0   178.05
# 4331     18283.0  2039.58
# 4332     18287.0  1837.28
#
# [4333 rows x 2 columns]

# %%
#last date available in our dataset
data['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
import datetime as dt
now = dt.date(2011,12,9)
print(now)
# Out:
# 2011-12-09

# %%
#create a new column called date which contains the date of invoice only
data['date'] = pd.DatetimeIndex(data['InvoiceDate']).date

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Amount  \
# ...

# %%
#group by customers and check last date of purshace
recency_data = data.groupby(by='CustomerID', as_index=False)['date'].max()
recency_data.columns = ['CustomerID','LastPurshaceDate']
recency_data.head()
# Out:
#    CustomerID LastPurshaceDate
# 0     12347.0       2011-12-07
# 1     12348.0       2011-09-25
# 2     12349.0       2011-11-21
# 3     12350.0       2011-02-02
# 4     12352.0       2011-11-03

# %%
#calculate recency
recency_data['Recency'] = recency_data['LastPurshaceDate'].apply(lambda x: (now - x).days)
recency_data.head()
# Out:
#    CustomerID LastPurshaceDate  Recency
# 0     12347.0       2011-12-07        2
# 1     12348.0       2011-09-25       75
# 2     12349.0       2011-11-21       18
# 3     12350.0       2011-02-02      310
# 4     12352.0       2011-11-03       36

# %%
#drop LastPurchaseDate as we don't need it anymore
recency_data.drop('LastPurshaceDate',axis=1,inplace=True)

# %%
recency_data
# Out:
#       CustomerID  Recency
# 0        12347.0        2
# 1        12348.0       75
# 2        12349.0       18
# 3        12350.0      310
# 4        12352.0       36
# ...          ...      ...
# 4328     18280.0      277
# 4329     18281.0      180
# 4330     18282.0        7
# 4331     18283.0        3
# 4332     18287.0       42
#
# [4333 rows x 2 columns]

# %%
# drop duplicates
dfc = data
dfc.drop_duplicates(subset=['InvoiceNo', 'CustomerID'], keep="first", inplace=True)
#calculate frequency of purchases
frequency_data = dfc.groupby(by=['CustomerID'], as_index=False)['InvoiceNo'].count()
frequency_data.columns = ['CustomerID','Frequency']
frequency_data.head()
# Out:
#    CustomerID  Frequency
# 0     12347.0          7
# 1     12348.0          4
# 2     12349.0          1
# 3     12350.0          1
# 4     12352.0          7

# %%
monetary_data = data.groupby(by='CustomerID',as_index=False).agg({'Amount': 'sum'})
monetary_data.columns = ['CustomerID','Monetary']
monetary_data
# Out:
#       CustomerID  Monetary
# 0        12347.0    163.16
# 1        12348.0    331.36
# 2        12349.0     15.00
# 3        12350.0     25.20
# 4        12352.0    159.80
# ...          ...       ...
# 4328     18280.0     23.70
# 4329     18281.0      5.04
# 4330     18282.0     38.25
# 4331     18283.0     66.75
# 4332     18287.0     80.40
#
# [4333 rows x 2 columns]

# %%
#merge recency dataframe with frequency dataframe
temp_data = recency_data.merge(frequency_data,on='CustomerID')
temp_data.head()
# Out:
#    CustomerID  Recency  Frequency
# 0     12347.0        2          7
# 1     12348.0       75          4
# 2     12349.0       18          1
# 3     12350.0      310          1
# 4     12352.0       36          7

# %%
#merge with monetary dataframe to get a table with the 3 columns
rfm_data = temp_data.merge(monetary_data,on='CustomerID')
#use CustomerID as index
rfm_data.set_index('CustomerID',inplace=True)
#check the head
rfm_data.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12347.0           2          7    163.16
# 12348.0          75          4    331.36
# 12349.0          18          1     15.00
# 12350.0         310          1     25.20
# 12352.0          36          7    159.80

# %% [markdown]
# Customer segments with RFM Model

# %%
quantiles = rfm_data.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#       Recency  Frequency  Monetary
# 0.25     17.0        1.0      17.7
# 0.50     50.0        2.0      46.8
# 0.75    142.0        5.0     127.2

# %%
quantiles.to_dict()
# Out:
# {'Recency': {0.25: 17.0, 0.5: 50.0, 0.75: 142.0},
#  'Frequency': {0.25: 1.0, 0.5: 2.0, 0.75: 5.0},
#  'Monetary': {0.25: 17.700000000000003, 0.5: 46.8, 0.75: 127.2}}

# %%
# Arguments (x = value, p = recency, monetary_value, frequency, d = quartiles dict)
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4

# %%
#create rfm segmentation table
rfm_segmentation = rfm_data
rfm_segmentation['R_Quartile'] = rfm_segmentation['Recency'].apply(RScore, args=('Recency',quantiles,))
rfm_segmentation['F_Quartile'] = rfm_segmentation['Frequency'].apply(FMScore, args=('Frequency',quantiles,))
rfm_segmentation['M_Quartile'] = rfm_segmentation['Monetary'].apply(FMScore, args=('Monetary',quantiles,))

# %%
rfm_segmentation.head()
# Out:
#             Recency  Frequency  Monetary  R_Quartile  F_Quartile  M_Quartile
# CustomerID
# 12347.0           2          7    163.16           4           4           4
# 12348.0          75          4    331.36           2           3           4
# 12349.0          18          1     15.00           3           1           1
# 12350.0         310          1     25.20           1           1           2
# 12352.0          36          7    159.80           3           4           4

# %%
rfm_segmentation['RFMScore'] = rfm_segmentation.R_Quartile.map(str) \
                            + rfm_segmentation.F_Quartile.map(str) \
                            + rfm_segmentation.M_Quartile.map(str)
rfm_segmentation.head()
# Out:
#             Recency  Frequency  Monetary  R_Quartile  F_Quartile  M_Quartile  \
# CustomerID
# 12347.0           2          7    163.16           4           4           4
# 12348.0          75          4    331.36           2           3           4
# 12349.0          18          1     15.00           3           1           1
# 12350.0         310          1     25.20           1           1           2
# 12352.0          36          7    159.80           3           4           4
#
#            RFMScore
# CustomerID
# 12347.0         444
# 12348.0         234
# 12349.0         311
# 12350.0         112
# 12352.0         344

# %%
'''Best Recency score = 4: most recently purchase. 
   Best Frequency score = 4: most quantity purchase.
   Best Monetary score = 4: spent the most.'''
# Out:
# 'Best Recency score = 4: most recently purchase. \n   Best Frequency score = 4: most quantity purchase.\n   Best Monetary score = 4: spent the most.'

# %%
rfm_segmentation[rfm_segmentation['RFMScore']=='444'].sort_values('Monetary', ascending=False)
# Out:
#             Recency  Frequency  Monetary  R_Quartile  F_Quartile  M_Quartile  \
# CustomerID
# 18102.0           0         60  42053.60           4           4           4
# 17949.0           1         44  29519.69           4           4           4
# 17450.0           8         46  26768.97           4           4           4
# 14646.0           1         73  19045.06           4           4           4
# 16013.0           3         47  17895.28           4           4           4
# ...             ...        ...       ...         ...         ...         ...
# 13949.0           2          6    129.93           4           4           4
# 17412.0           2          7    129.76           4           4           4
# 12957.0           9          8    129.66           4           4           4
# 18044.0           4         10    127.46           4           4           4
# 15214.0           1          8    127.36           4           4           4
#
#            RFMScore
# ...

# %%
print("Best Customers: ",len(rfm_segmentation[rfm_segmentation['RFMScore']=='444']))
print('Loyal Customers: ',len(rfm_segmentation[rfm_segmentation['F_Quartile']==4]))
print("Big Spenders: ",len(rfm_segmentation[rfm_segmentation['M_Quartile']==4]))
print('Almost Lost: ', len(rfm_segmentation[rfm_segmentation['RFMScore']=='244']))
print('Lost Customers: ',len(rfm_segmentation[rfm_segmentation['RFMScore']=='144']))
print('Lost Cheap Customers: ',len(rfm_segmentation[rfm_segmentation['RFMScore']=='111']))
# Out:
# Best Customers:  405
# Loyal Customers:  869
# Big Spenders:  1083
# Almost Lost:  66
# Lost Customers:  11
# Lost Cheap Customers:  415

# %% [markdown]
# Check Skewness

# %%
from scipy import stats

# %%
## Function to check skewness
def check_skew(df_skew, column):
    skew = stats.skew(df_skew[column])
    skewtest = stats.skewtest(df_skew[column])
    plt.title('Distribution of ' + column)
    sns.distplot(df_skew[column])
    print("{}'s: Skew: {}, : {}".format(column, skew, skewtest))
    return

# %%
check_skew(rfm_segmentation, 'Monetary')
# Out:
# <ipython-input-295-0e30ba8c7352>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_skew[column])
# Monetary's: Skew: 19.924169108203593, : SkewtestResult(statistic=85.62675416140998, pvalue=0.0)

# %%
check_skew(rfm_segmentation, 'Recency')
# Out:
# <ipython-input-295-0e30ba8c7352>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_skew[column])
# Recency's: Skew: 1.2429210653169196, : SkewtestResult(statistic=26.551649997569942, pvalue=2.457965334149525e-155)

# %%
check_skew(rfm_segmentation, 'Frequency')
# Out:
# <ipython-input-295-0e30ba8c7352>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_skew[column])
# Frequency's: Skew: 11.934804580121844, : SkewtestResult(statistic=74.35008424005727, pvalue=0.0)

# %%
 df_rfm_log = rfm_segmentation[['Recency', 'Frequency', 'Monetary']]

# %%
df_rfm_log
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12347.0           2          7    163.16
# 12348.0          75          4    331.36
# 12349.0          18          1     15.00
# 12350.0         310          1     25.20
# 12352.0          36          7    159.80
# ...             ...        ...       ...
# 18280.0         277          1     23.70
# 18281.0         180          1      5.04
# 18282.0           7          2     38.25
# 18283.0           3         16     66.75
# 18287.0          42          3     80.40
#
# [4333 rows x 3 columns]

# %% [markdown]
# Removing skewness

# %%
#RECENCY
df_rfm_log['Recency'] = np.log(df_rfm_log['Recency']+1)
plt.figure(figsize=(9, 9))
plt.subplot(3, 1, 1)
check_skew(df_rfm_log,'Recency')
# Out:
# <ipython-input-301-1a65d20599e3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rfm_log['Recency'] = np.log(df_rfm_log['Recency']+1)
# <ipython-input-295-0e30ba8c7352>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_skew[column])
# Recency's: Skew: -0.4647870163117142, : SkewtestResult(statistic=-11.92172468764053, pvalue=9.120077900403409e-33)

# %%
#FREQUENCY
df_rfm_log['Frequency'] = np.log(df_rfm_log['Frequency']+1)
plt.figure(figsize=(9, 9))
plt.subplot(3, 1, 1)
check_skew(df_rfm_log,'Frequency')
# Out:
# <ipython-input-302-15c3628d73f5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rfm_log['Frequency'] = np.log(df_rfm_log['Frequency']+1)
# <ipython-input-295-0e30ba8c7352>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_skew[column])
# Frequency's: Skew: 1.2116364222913556, : SkewtestResult(statistic=26.084321021481628, pvalue=5.491888767420604e-150)

# %%
#MONETARY
df_rfm_log['Monetary'] = np.log(df_rfm_log['Monetary']+1)
plt.figure(figsize=(9, 9))
plt.subplot(3, 1, 1)
check_skew(df_rfm_log,'Monetary')
# Out:
# <ipython-input-303-51f0f948b2f2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rfm_log['Monetary'] = np.log(df_rfm_log['Monetary']+1)
# <ipython-input-295-0e30ba8c7352>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_skew[column])
# Monetary's: Skew: 0.5084284330429804, : SkewtestResult(statistic=12.931565930381288, pvalue=2.9867298635950666e-38)

# %% [markdown]
# Clustering: K-Means [Using RFM values]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_rfm_log)
RFM_Table_scaled = scaler.transform(df_rfm_log)

# %%
'''to convert the numpy array RFM_Table_scaled to a pandas DataFrame, so that it can be more easily used and manipulated for analysis or modeling purposes'''

RFM_Table_scaled = pd.DataFrame(RFM_Table_scaled, columns = df_rfm_log.columns)

# %%
RFM_Table_scaled = RFM_Table_scaled.set_index(df_rfm_log.index)

# %%
RFM_Table_scaled.head()
# Out:
#              Recency  Frequency  Monetary
# CustomerID
# 12347.0    -1.955731   1.078626  0.783307
# 12348.0     0.381828   0.389704  1.271374
# 12349.0    -0.620778  -0.953376 -0.827663
# 12350.0     1.400899  -0.953376 -0.486427
# 12352.0    -0.138762   1.078626  0.768998

# %%
# ELBOW METHOD

from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {} 
K = range(1,10) 
  
for k in K: 
    #Building and fitting the model 
    kmeanModel = KMeans(n_clusters=k).fit(RFM_Table_scaled) 
    kmeanModel.fit(RFM_Table_scaled)     
      
    distortions.append(sum(np.min(cdist(RFM_Table_scaled, kmeanModel.cluster_centers_, 
                      'euclidean'),axis=1)) / RFM_Table_scaled.shape[0]) 
    inertias.append(kmeanModel.inertia_) 
  
    mapping1[k] = sum(np.min(cdist(RFM_Table_scaled, kmeanModel.cluster_centers_, 
                 'euclidean'),axis=1)) / RFM_Table_scaled.shape[0] 
    mapping2[k] = kmeanModel.inertia_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(K, inertias, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Inertia')
plt.title('The Elbow method using Inertia')
plt.show()

# %%
from sklearn.manifold import TSNE

# %%
def kmeans(normalised_df_rfm, clusters_number, original_df_rfm):
    
    kmeans = KMeans(n_clusters = clusters_number, random_state = 1)
    kmeans.fit(normalised_df_rfm)
    # Extract cluster labels
    cluster_labels = kmeans.labels_
        
    # Create a cluster label column in original dataset
    df_new = original_df_rfm.assign(Cluster = cluster_labels)
    
    # Initialise TSNE
    model = TSNE(random_state=1)
    transformed = model.fit_transform(df_new)
    
    return df_new, transformed

# %%
import seaborn as sns

# call the kmeans function and store the DataFrame with cluster labels and the transformed variable in separate variables
df_rfm_k3, transformed_k3 = kmeans(RFM_Table_scaled, 3, df_rfm_log)
df_rfm_k4, transformed_k4 = kmeans(RFM_Table_scaled, 4, df_rfm_log)
df_rfm_k5, transformed_k5 = kmeans(RFM_Table_scaled, 5, df_rfm_log)

# generate a color palette with the same number of colors as the number of clusters
palette = sns.color_palette("Set1", n_colors=len(set(df_rfm_k3['Cluster'])))

# plot the data points with the assigned colors
plt.figure(figsize=(10, 10))
plt.subplot(3, 1, 1)
sns.scatterplot(x=transformed_k3[:,0], y=transformed_k3[:,1], hue=df_rfm_k3['Cluster'], palette=palette)
plt.subplot(3, 1, 2)
sns.scatterplot(x=transformed_k4[:,0], y=transformed_k4[:,1], hue=df_rfm_k4['Cluster'], palette=palette)
plt.subplot(3, 1, 3)
sns.scatterplot(x=transformed_k5[:,0], y=transformed_k5[:,1], hue=df_rfm_k5['Cluster'], palette=palette)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-312-3a7ca3a7274f>:16: UserWarning:
# The palette list has fewer values (3) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x=transformed_k4[:,0], y=transformed_k4[:,1], hue=df_rfm_k4['Cluster'], palette=palette)
# ...

# %%
import seaborn as sns

# generate a color palette with 3 colors for 3 clusters
palette = sns.color_palette()
palette
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
df_rfm_k3
# Out:
#              Recency  Frequency  Monetary  Cluster
# CustomerID
# 12347.0     1.098612   2.079442  5.100842        2
# 12348.0     4.330733   1.609438  5.806219        1
# 12349.0     2.944439   0.693147  2.772589        0
# 12350.0     5.739793   0.693147  3.265759        0
# 12352.0     3.610918   2.079442  5.080161        1
# ...              ...        ...       ...      ...
# 18280.0     5.627621   0.693147  3.206803        0
# 18281.0     5.198497   0.693147  1.798404        0
# 18282.0     2.079442   1.098612  3.669951        1
# 18283.0     1.386294   2.833213  4.215824        2
# 18287.0     3.761200   1.386294  4.399375        1
#
# [4333 rows x 4 columns]

# %%
def rfm_values(df):
    df_new = df.groupby(['Cluster']).agg({
        'Recency': 'mean',
        'Frequency': 'mean',
        'Monetary': ['mean', 'count']
    }).round(0)
    
    return df_new

# %%
rfm_values(df_rfm_k3)
# Out:
#         Recency Frequency Monetary
#            mean      mean     mean count
# Cluster
# 0           5.0       1.0      3.0  1920
# 1           3.0       1.0      4.0  1704
# 2           2.0       2.0      6.0   709

# %%
rfm_values(df_rfm_k4)
# Out:
#         Recency Frequency Monetary
#            mean      mean     mean count
# Cluster
# 0           4.0       2.0      5.0  1157
# 1           2.0       2.0      6.0   715
# 2           5.0       1.0      3.0  1567
# 3           3.0       1.0      3.0   894

# %%
rfm_values(df_rfm_k5)
# Out:
#         Recency Frequency Monetary
#            mean      mean     mean count
# Cluster
# 0           3.0       2.0      5.0   943
# 1           5.0       1.0      3.0  1202
# 2           3.0       1.0      3.0   836
# 3           2.0       3.0      7.0   301
# 4           5.0       1.0      4.0  1051

# %% [markdown]
# ASSOCIATIVE RULE MINING -  USING APRIORI ALGORITNM

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
# Check each stock code has only one description
df.groupby('StockCode').apply(lambda x: x['Description'].unique())
# Out:
# StockCode
# 10002                          [INFLATABLE POLITICAL GLOBE , nan]
# 10080                      [GROOVY CACTUS INFLATABLE, nan, check]
# 10120                                              [DOGGY RUBBER]
# 10125                                   [MINI FUNKY DESIGN TAPES]
# 10133                     [COLOURING PENCILS BROWN TUBE, damaged]
#                                       ...
# gift_0001_20    [Dotcomgiftshop Gift Voucher £20.00, to push o...
# gift_0001_30            [Dotcomgiftshop Gift Voucher £30.00, nan]
# gift_0001_40                 [Dotcomgiftshop Gift Voucher £40.00]
# gift_0001_50                 [Dotcomgiftshop Gift Voucher £50.00]
# m                                                        [Manual]
# Length: 4070, dtype: object

# %%
df.shape
# Out:
# (541909, 8)

# %%
# Number of invoices for each country
df.groupby(['Country']).count() ['InvoiceNo']
# Out:
# Country
# Australia                 1259
# Austria                    401
# Bahrain                     19
# Belgium                   2069
# Brazil                      32
# Canada                     151
# Channel Islands            758
# Cyprus                     622
# Czech Republic              30
# Denmark                    389
# EIRE                      8196
# European Community          61
# Finland                    695
# France                    8557
# Germany                   9495
# Greece                     146
# Hong Kong                  288
# Iceland                    182
# Israel                     297
# Italy                      803
# Japan                      358
# Lebanon                     45
# Lithuania                   35
# Malta                      127
# Netherlands               2371
# Norway                    1086
# Poland                     341
# Portugal                  1519
# RSA                         58
# Saudi Arabia                10
# ...

# %%
# Delete rows with null CustomerID
clean_df = df.dropna(subset = ['CustomerID'])

# Check null values
clean_df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# Removing the price and quantity that are less than or equal to 0
clean_df = clean_df[(clean_df.Quantity >= 0) & (clean_df.UnitPrice >= 0)]
clean_df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  397924.000000  397924.000000  397924.000000
# mean       13.021823       3.116174   15294.315171
# std       180.420210      22.096788    1713.169877
# min         1.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13969.000000
# 50%         6.000000       1.950000   15159.000000
# 75%        12.000000       3.750000   16795.000000
# max     80995.000000    8142.750000   18287.000000

# %%
# Check the number of invoices that starts with letter 'c', cancellation.
clean_df['InvoiceNo'] = clean_df['InvoiceNo'].astype('str')
clean_df[clean_df['InvoiceNo'].str.contains("c")].shape[0]
# Out:
# <ipython-input-328-23de4ebab20c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['InvoiceNo'] = clean_df['InvoiceNo'].astype('str')
# 0

# %%
# Check the stock code

import re

def has_right_scode(input):
    
    """
    Function: check the if the stock code is written in a right way,
            The function check if the code contains 5-digit number or 5-digit number with a letter.
    Args:
      input(String): Stock code
    Return:
      Boolean: True or False
    """
    
    x = re.search("^\d{5}$", input)
    y = re.search("^\d{5}[a-zA-Z]{1}$", input)
    if (x or y):
        return True
    else:
        return False

    
clean_df['StockCode'] = clean_df['StockCode'].astype('str')
clean_df = clean_df[clean_df['StockCode'].apply(has_right_scode) == True]
clean_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# One discription for each stock code

# Put all Descriptions of each StockCode in a list 
df_itms = pd.DataFrame(clean_df.groupby('StockCode').apply(lambda x: x['Description'].unique())).reset_index()
df_itms.rename(columns = { 0: 'Description2'}, inplace = True)

# StockCode that have more than one Description
df_itms[df_itms['Description2'].str.len() != 1]
# Out:
#      StockCode                                       Description2
# 41      16156L                    [WRAP, CAROUSEL, WRAP CAROUSEL]
# 99      17107D  [FLOWER FAIRY,5 SUMMER B'DRAW LINERS, FLOWER F...
# 117      20622          [VIPPASSPORT COVER , VIP PASSPORT COVER ]
# 169      20725    [LUNCH BAG RED RETROSPOT, LUNCH BAG RED SPOTTY]
# 261      20914  [SET/5 RED RETROSPOT LID GLASS BOWLS, SET/5 RE...
# ...        ...                                                ...
# 3292    85184C  [S/4 VALENTINE DECOUPAGE HEART BOX, SET 4 VALE...
# 3293    85185B  [PINK HORSE SOCK PUPPET, PINK HORSE SOCK PUPPE...
# 3356    90014A  [SILVER/MOP ORBIT NECKLACE, SILVER M.O.P. ORBI...
# 3357    90014B  [GOLD M PEARL  ORBIT NECKLACE, GOLD M.O.P. ORB...
# 3358    90014C  [SILVER/BLACK ORBIT NECKLACE, SILVER AND BLACK...
#
# [213 rows x 2 columns]

# %%
# Merge clean_df with df_itms
clean_df = pd.merge(clean_df, df_itms, on = 'StockCode')
clean_df = clean_df.drop('Description', axis = 1)
clean_df.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1    536373    85123A         6 2010-12-01 09:02:00       2.55     17850.0
# 2    536375    85123A         6 2010-12-01 09:32:00       2.55     17850.0
# 3    536390    85123A        64 2010-12-01 10:19:00       2.55     17511.0
# 4    536394    85123A        32 2010-12-01 10:39:00       2.55     13408.0
#
#           Country                                       Description2
# 0  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...
# 1  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...
# 2  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...
# 3  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...
# 4  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...

# %%
clean_df.rename(columns = { 'Description2': 'Description'}, inplace = True)
clean_df.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1    536373    85123A         6 2010-12-01 09:02:00       2.55     17850.0
# 2    536375    85123A         6 2010-12-01 09:32:00       2.55     17850.0
# 3    536390    85123A        64 2010-12-01 10:19:00       2.55     17511.0
# 4    536394    85123A        32 2010-12-01 10:39:00       2.55     13408.0
#
#           Country                                        Description
# 0  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...
# 1  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...
# 2  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...
# 3  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...
# 4  United Kingdom  [WHITE HANGING HEART T-LIGHT HOLDER, CREAM HAN...

# %%
print(clean_df['Description'].dtype)
# Out:
# object

# %%
clean_df['Description'] = clean_df['Description'].astype(str)
df_itms_togthr = clean_df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().fillna(0)
df_itms_togthr
# Out:
# Description  [" 50'S CHRISTMAS GIFT BAG LARGE" "GIFT BAG LARGE 50'S CHRISTMAS"]  \
# InvoiceNo
# 536365                                                     0.0
# 536366                                                     0.0
# 536367                                                     0.0
# 536368                                                     0.0
# 536369                                                     0.0
# ...                                                        ...
# 581583                                                     0.0
# 581584                                                     0.0
# 581585                                                     0.0
# 581586                                                     0.0
# 581587                                                     0.0
#
# Description  ["3 RAFFIA RIBBONS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536365                                        0.0
# 536366                                        0.0
# ...

# %%
df_itms_togthr = clean_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()
df_itms_togthr.head()
# Out:
# InvoiceNo  Description
# 536365     ['CREAM CUPID HEARTS COAT HANGER']         8
#            ['GLASS STAR FROSTED T-LIGHT HOLDER']      6
#            ['KNITTED UNION FLAG HOT WATER BOTTLE']    6
#            ['RED WOOLLY HOTTIE WHITE HEART.']         6
#            ['SET 7 BABUSHKA NESTING BOXES']           2
# Name: Quantity, dtype: int64

# %%
# Encode the frequency of description to 0 or 1
encode = lambda x: 1 if (x >= 1) else 0
df_itms_togthr = df_itms_togthr.apply(encode)
df_itms_togthr.head()
# Out:
# InvoiceNo  Description
# 536365     ['CREAM CUPID HEARTS COAT HANGER']         1
#            ['GLASS STAR FROSTED T-LIGHT HOLDER']      1
#            ['KNITTED UNION FLAG HOT WATER BOTTLE']    1
#            ['RED WOOLLY HOTTIE WHITE HEART.']         1
#            ['SET 7 BABUSHKA NESTING BOXES']           1
# Name: Quantity, dtype: int64

# %%
df_itms_togthr
# Out:
# InvoiceNo  Description
# 536365     ['CREAM CUPID HEARTS COAT HANGER']         1
#            ['GLASS STAR FROSTED T-LIGHT HOLDER']      1
#            ['KNITTED UNION FLAG HOT WATER BOTTLE']    1
#            ['RED WOOLLY HOTTIE WHITE HEART.']         1
#            ['SET 7 BABUSHKA NESTING BOXES']           1
#                                                      ..
# 581587     ['CIRCUS PARADE LUNCH BOX ']               1
#            ['PACK OF 20 SPACEBOY NAPKINS']            1
#            ['PLASTERS IN TIN CIRCUS PARADE ']         1
#            ['PLASTERS IN TIN STRONGMAN']              1
#            ['SPACEBOY LUNCH BOX ']                    1
# Name: Quantity, Length: 385963, dtype: int64

# %% [markdown]
# Netherlands, Spain, France Countries Data

# %%
nl_df = clean_df[clean_df['Country'] == 'Netherlands']
spain_df = clean_df[clean_df['Country'] == 'Spain']
france_df = clean_df[clean_df['Country'] == 'France']
uk_df = clean_df[clean_df['Country']== 'United Kingdom']
ger_df = clean_df[clean_df['Country']== 'Germany']
eire_df = clean_df[clean_df['Country']== 'EIRE']
bel_df = clean_df[clean_df['Country']== 'Belgium']
switz_df = clean_df[clean_df['Country']== 'Switzerland']
port_df = clean_df[clean_df['Country']== 'Portugal']
aust_df = clean_df[clean_df['Country']== 'Australia']

# %%
uk_df
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 0         536365    85123A         6 2010-12-01 08:26:00       2.55
# 1         536373    85123A         6 2010-12-01 09:02:00       2.55
# 2         536375    85123A         6 2010-12-01 09:32:00       2.55
# 3         536390    85123A        64 2010-12-01 10:19:00       2.55
# 4         536394    85123A        32 2010-12-01 10:39:00       2.55
# ...          ...       ...       ...                 ...        ...
# 396074    580691    90214Z        12 2011-12-05 15:48:00       0.29
# 396075    580865     90089        12 2011-12-06 11:58:00       0.19
# 396076    580865     90089        12 2011-12-06 11:58:00       0.19
# 396077    581425     90089         1 2011-12-08 15:31:00       0.19
# 396078    581483     23843     80995 2011-12-09 09:15:00       2.08
#
#         CustomerID         Country  \
# 0          17850.0  United Kingdom
# 1          17850.0  United Kingdom
# 2          17850.0  United Kingdom
# ...

# %%
port_df
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 183       539353    85123A         6 2010-12-17 11:30:00       2.95
# 662       548470    85123A        12 2011-03-31 12:36:00       2.95
# 4263      570964     22632        12 2011-10-13 11:50:00       2.10
# 4716      545937     84879        24 2011-03-08 12:05:00       1.69
# 4798      548470     84879         8 2011-03-31 12:36:00       1.69
# ...          ...       ...       ...                 ...        ...
# 394909    578488     23581        10 2011-11-24 12:53:00       2.08
# 394974    580734     23581        30 2011-12-06 08:46:00       2.08
# 395324    575743     23681        30 2011-11-11 10:01:00       1.65
# 395430    574844    90162A         6 2011-11-07 11:57:00       2.95
# 395755    580153     23552         6 2011-12-02 10:23:00       2.08
#
#         CustomerID   Country  \
# 183        12782.0  Portugal
# 662        12782.0  Portugal
# 4263       12766.0  Portugal
# ...

# %%
spain_df.head()
# Out:
#      InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 103     538095    85123A         1 2010-12-09 14:55:00       2.95     17097.0
# 240     540469    85123A         6 2011-01-07 14:04:00       2.95     12484.0
# 417     543541    85123A         6 2011-02-09 14:44:00       2.95     12462.0
# 1180    559665    85123A         2 2011-07-11 13:35:00       2.95     12556.0
# 1262    561093    85123A        12 2011-07-25 10:01:00       2.95     12540.0
#
#      Country                                        Description
# 103    Spain  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 240    Spain  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 417    Spain  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 1180   Spain  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 1262   Spain  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...

# %%
nl_df.head()
# Out:
#      InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 304     541570    85123A       256 2011-01-19 12:34:00       2.55     14646.0
# 534     546027    85123A        12 2011-03-09 08:09:00       2.95     12759.0
# 606     547365    85123A        12 2011-03-22 12:36:00       2.95     12775.0
# 1111    557525    85123A         6 2011-06-21 09:26:00       2.95     12759.0
# 1672    571697    85123A         6 2011-10-18 14:49:00       2.95     12759.0
#
#           Country                                        Description
# 304   Netherlands  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 534   Netherlands  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 606   Netherlands  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 1111  Netherlands  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 1672  Netherlands  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...

# %%
france_df.head()
# Out:
#      InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 807     551163    85123A         9 2011-04-26 15:52:00       2.95     12573.0
# 1379    563502    85123A        32 2011-08-17 08:50:00       2.55     12722.0
# 1931    578541    85123A         8 2011-11-24 15:01:00       2.95     14277.0
# 2645    540976    84029G         4 2011-01-12 15:00:00       3.75     12652.0
# 2706    566816    84029G        12 2011-09-15 10:53:00       4.25     12731.0
#
#      Country                                        Description
# 807   France  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 1379  France  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 1931  France  ['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM H...
# 2645  France            ['KNITTED UNION FLAG HOT WATER BOTTLE']
# 2706  France            ['KNITTED UNION FLAG HOT WATER BOTTLE']

# %% [markdown]
#  Here I am subsequently grouping each country, using apriori algorithm

# %%
df_itms_togthr_uk = uk_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_uk = df_itms_togthr_uk.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_uk = df_itms_togthr_uk.applymap(encode)
df_itms_togthr_uk.head()
# Out:
# Description  [" 50'S CHRISTMAS GIFT BAG LARGE" "GIFT BAG LARGE 50'S CHRISTMAS"]  \
# InvoiceNo
# 536365                                                       0
# 536366                                                       0
# 536367                                                       0
# 536368                                                       0
# 536369                                                       0
#
# Description  ["3 RAFFIA RIBBONS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536365                                          0
# 536366                                          0
# 536367                                          0
# 536368                                          0
# 536369                                          0
#
# Description  ["50'S CHRISTMAS PAPER GIFT BAG"]  \
# InvoiceNo
# 536365                                       0
# 536366                                       0
# 536367                                       0
# ...

# %%
df_itms_togthr_nl = nl_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_nl = df_itms_togthr_nl.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_nl = df_itms_togthr_nl.applymap(encode)
df_itms_togthr_nl.head()
# Out:
# Description  ["3 RAFFIA RIBBONS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536403                                          0
# 539491                                          0
# 539731                                          0
# 541206                                          0
# 541570                                          0
#
# Description  ["CHILDREN'S APRON DOLLY GIRL "]  \
# InvoiceNo
# 536403                                      0
# 539491                                      0
# 539731                                      0
# 541206                                      1
# 541570                                      1
#
# Description  ["CHILDREN'S CIRCUS PARADE MUG"]  \
# InvoiceNo
# 536403                                      0
# 539491                                      0
# 539731                                      0
# 541206                                      0
# 541570                                      0
#
# ...

# %%
df_itms_togthr_spain = spain_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_spain = df_itms_togthr_spain.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_spain = df_itms_togthr_spain.applymap(encode)
df_itms_togthr_spain.head()
# Out:
# Description  [" 50'S CHRISTMAS GIFT BAG LARGE" "GIFT BAG LARGE 50'S CHRISTMAS"]  \
# InvoiceNo
# 536944                                                       0
# 538095                                                       0
# 538525                                                       0
# 539351                                                       0
# 540469                                                       0
#
# Description  ["3 RAFFIA RIBBONS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536944                                          0
# 538095                                          0
# 538525                                          0
# 539351                                          0
# 540469                                          0
#
# Description  ["6 GIFT TAGS 50'S CHRISTMAS "]  ["BISCUIT TIN 50'S CHRISTMAS"]  \
# InvoiceNo
# 536944                                     0                               0
# ...

# %%
df_itms_togthr_france = france_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_france = df_itms_togthr_france.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_france = df_itms_togthr_france.applymap(encode)
df_itms_togthr_france.head()
# Out:
# Description  [" 50'S CHRISTMAS GIFT BAG LARGE" "GIFT BAG LARGE 50'S CHRISTMAS"]  \
# InvoiceNo
# 536370                                                       0
# 536852                                                       0
# 536974                                                       0
# 537065                                                       0
# 537463                                                       0
#
# Description  ["3 RAFFIA RIBBONS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536370                                          0
# 536852                                          0
# 536974                                          0
# 537065                                          0
# 537463                                          0
#
# Description  ["6 GIFT TAGS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536370                                     0
# 536852                                     0
# 536974                                     0
# ...

# %%
df_itms_togthr_ger = ger_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_ger = df_itms_togthr_ger.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_ger = df_itms_togthr_ger.applymap(encode)
df_itms_togthr_ger.head()
# Out:
# Description  [" 50'S CHRISTMAS GIFT BAG LARGE" "GIFT BAG LARGE 50'S CHRISTMAS"]  \
# InvoiceNo
# 536527                                                       0
# 536840                                                       0
# 536861                                                       0
# 536967                                                       0
# 536983                                                       0
#
# Description  ["3 RAFFIA RIBBONS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536527                                          0
# 536840                                          0
# 536861                                          0
# 536967                                          0
# 536983                                          0
#
# Description  ["50'S CHRISTMAS PAPER GIFT BAG"]  \
# InvoiceNo
# 536527                                       0
# 536840                                       0
# 536861                                       0
# ...

# %%
df_itms_togthr_eire = eire_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_eire = df_itms_togthr_eire.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_eire = df_itms_togthr_eire.applymap(encode)
df_itms_togthr_eire.head()
# Out:
# Description  [" 50'S CHRISTMAS GIFT BAG LARGE" "GIFT BAG LARGE 50'S CHRISTMAS"]  \
# InvoiceNo
# 536540                                                       0
# 536541                                                       0
# 536803                                                       0
# 536890                                                       0
# 536975                                                       0
#
# Description  ["3 RAFFIA RIBBONS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536540                                          0
# 536541                                          0
# 536803                                          0
# 536890                                          0
# 536975                                          0
#
# Description  ["6 GIFT TAGS 50'S CHRISTMAS "]  \
# InvoiceNo
# 536540                                     0
# 536541                                     0
# 536803                                     0
# ...

# %%
df_itms_togthr_bel = bel_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_bel = df_itms_togthr_bel.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_bel = df_itms_togthr_bel.applymap(encode)
df_itms_togthr_bel.head()
# Out:
# Description  ["6 GIFT TAGS 50'S CHRISTMAS "]  ["BISCUIT TIN 50'S CHRISTMAS"]  \
# InvoiceNo
# 537026                                     0                               0
# 539391                                     0                               0
# 539447                                     0                               0
# 539676                                     0                               0
# 539840                                     0                               0
#
# Description  ["BOX OF 6 MINI 50'S CRACKERS"]  \
# InvoiceNo
# 537026                                     0
# 539391                                     0
# 539447                                     0
# 539676                                     0
# 539840                                     0
#
# Description  ["CHILDREN'S APRON DOLLY GIRL "]  \
# InvoiceNo
# 537026                                      0
# 539391                                      0
# 539447                                      0
# ...

# %%
df_itms_togthr_switz = switz_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_switz = df_itms_togthr_switz.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_switz = df_itms_togthr_switz.applymap(encode)
df_itms_togthr_switz.head()
# Out:
# Description  ["BISCUIT TIN 50'S CHRISTMAS"]  \
# InvoiceNo
# 536858                                    0
# 539488                                    0
# 541518                                    0
# 541569                                    0
# 542586                                    0
#
# Description  ["BLACK SIL'T SQU CANDLE PLATE "]  \
# InvoiceNo
# 536858                                       0
# 539488                                       0
# 541518                                       0
# 541569                                       0
# 542586                                       0
#
# Description  ["BOX OF 6 MINI 50'S CRACKERS"]  \
# InvoiceNo
# 536858                                     0
# 539488                                     0
# 541518                                     0
# 541569                                     0
# 542586                                     0
#
# Description  ["CHILDREN'S CIRCUS PARADE MUG"]  \
# InvoiceNo
# ...

# %%
df_itms_togthr_port = port_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_port = df_itms_togthr_port.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_port = df_itms_togthr_port.applymap(encode)
df_itms_togthr_port.head()
# Out:
# Description  [" 50'S CHRISTMAS GIFT BAG LARGE" "GIFT BAG LARGE 50'S CHRISTMAS"]  \
# InvoiceNo
# 536990                                                       0
# 537246                                                       0
# 537818                                                       0
# 537915                                                       0
# 538311                                                       0
#
# Description  ["50'S CHRISTMAS PAPER GIFT BAG"]  \
# InvoiceNo
# 536990                                       0
# 537246                                       0
# 537818                                       0
# 537915                                       0
# 538311                                       0
#
# Description  ["6 GIFT TAGS 50'S CHRISTMAS "]  ["BISCUIT TIN 50'S CHRISTMAS"]  \
# InvoiceNo
# 536990                                     0                               0
# 537246                                     0                               0
# ...

# %%
df_itms_togthr_aust = aust_df.groupby(['InvoiceNo','Description'])['Quantity'].sum()

df_itms_togthr_aust = df_itms_togthr_aust.unstack().fillna(0)

encode = lambda x : 1 if (x >= 1) else 0
df_itms_togthr_aust = df_itms_togthr_aust.applymap(encode)
df_itms_togthr_aust.head()
# Out:
# Description  ["70'S ALPHABET WALL ART" "WALL ART 70'S ALPHABET "]  \
# InvoiceNo
# 536389                                                       0
# 537676                                                       0
# 539419                                                       0
# 540267                                                       0
# 540280                                                       0
#
# Description  ["BISCUIT TIN 50'S CHRISTMAS"]  ["BOX OF 6 MINI 50'S CRACKERS"]  \
# InvoiceNo
# 536389                                    0                                0
# 537676                                    0                                0
# 539419                                    0                                0
# 540267                                    0                                0
# 540280                                    0                                0
#
# Description  ["CHILDREN'S CIRCUS PARADE MUG"]  ["DOCTOR'S BAG SOFT TOY"]  \
# InvoiceNo
# ...

# %% [markdown]
# All Countries Data

# %%
# Create a pivot table with binary indicators
df_pivot = clean_df.pivot_table(index='InvoiceNo', columns='Description', values='Quantity', aggfunc='sum', fill_value=0)

# Convert the frequency values to binary indicators
df_pivot[df_pivot > 0] = 1

# Build the Apriori model
rep_items = apriori(df_pivot, min_support=0.02, use_colnames=True)

# Generate association rules
rules = association_rules(rep_items, metric='lift')
rules
# Out:
#                                           antecedents  \
# 0               (["PAPER CHAIN KIT 50'S CHRISTMAS "])
# 1             (['PAPER CHAIN KIT VINTAGE CHRISTMAS'])
# 2                    (['ALARM CLOCK BAKELIKE GREEN'])
# 3                     (['ALARM CLOCK BAKELIKE RED '])
# 4                     (['ALARM CLOCK BAKELIKE PINK'])
# ..                                                ...
# 83  (['ROSES REGENCY TEACUP AND SAUCER '], ['GREEN...
# 84  (['PINK REGENCY TEACUP AND SAUCER'], ['GREEN R...
# 85             (['ROSES REGENCY TEACUP AND SAUCER '])
# 86               (['PINK REGENCY TEACUP AND SAUCER'])
# 87              (['GREEN REGENCY TEACUP AND SAUCER'])
#
#                                           consequents  antecedent support  \
# 0             (['PAPER CHAIN KIT VINTAGE CHRISTMAS'])            0.053249
# 1               (["PAPER CHAIN KIT 50'S CHRISTMAS "])            0.037872
# 2                     (['ALARM CLOCK BAKELIKE RED '])            0.042871
# ...

# %% [markdown]
# Explanation of the above code : lift as a metric, helps identify more meaningful rules, as it considers both the support of the itemsets and the probability of them occurring together
#
# min_threshold=1, as we are asking the function to return all the rules without applying any threshold
#
# A minimum support of 0.02 means that an itemset must appear in at least 2% of the transactions to be considered frequent. A lower minimum support will result in more frequent itemsets, but the analysis may also be more computationally intensive A higher minimum support will result in fewer frequent itemsets, but the analysis may be less informative.
#
# We use the metric lift for all countries as we are looking for rules that have a strong relationship between the antecedent and the consequent across all countries. The lift metric measures the degree of association between two items, beyond what would be expected by chance.

# %% [markdown]
# Remove the duplicate rules

# %%
# Create a copy of the rules dataframe
cleaned_rules = rules.copy()

# Loop through each rule
for i, rule in rules.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules['antecedents'].isin([rule['consequents']]) & cleaned_rules['consequents'].isin([rule['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules = cleaned_rules.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules = cleaned_rules.reset_index(drop=True)

# Print the cleaned rules dataframe
print(cleaned_rules)
# Out:
#                                           antecedents  \
# 0             (['PAPER CHAIN KIT VINTAGE CHRISTMAS'])
# 1                     (['ALARM CLOCK BAKELIKE RED '])
# 2                     (['ALARM CLOCK BAKELIKE RED '])
# 3                          (['DOLLY GIRL LUNCH BOX'])
# 4            (['GARDENERS KNEELING PAD CUP OF TEA '])
# 5               (['GREEN REGENCY TEACUP AND SAUCER'])
# 6               (['GREEN REGENCY TEACUP AND SAUCER'])
# 7               (['GREEN REGENCY TEACUP AND SAUCER'])
# 8                         (['HEART OF WICKER SMALL'])
# 9   (['JUMBO BAG DOILEY PATTERNS' 'JUMBO BAG VINTA...
# 10                       (['JUMBO BAG VINTAGE LEAF'])
# 11  (['JUMBO BAG DOILEY PATTERNS' 'JUMBO BAG VINTA...
# 12                      (['JUMBO BAG RED RETROSPOT'])
# 13                      (['JUMBO BAG RED RETROSPOT'])
# 14            (['JUMBO SHOPPER VINTAGE RED PAISLEY'])
# 15                       (['JUMBO STORAGE BAG SUKI'])
# ...

# %%
cleaned_rules = pd.DataFrame(data=cleaned_rules)
cleaned_rules
# Out:
#                                           antecedents  \
# 0             (['PAPER CHAIN KIT VINTAGE CHRISTMAS'])
# 1                     (['ALARM CLOCK BAKELIKE RED '])
# 2                     (['ALARM CLOCK BAKELIKE RED '])
# 3                          (['DOLLY GIRL LUNCH BOX'])
# 4            (['GARDENERS KNEELING PAD CUP OF TEA '])
# 5               (['GREEN REGENCY TEACUP AND SAUCER'])
# 6               (['GREEN REGENCY TEACUP AND SAUCER'])
# 7               (['GREEN REGENCY TEACUP AND SAUCER'])
# 8                         (['HEART OF WICKER SMALL'])
# 9   (['JUMBO BAG DOILEY PATTERNS' 'JUMBO BAG VINTA...
# 10                       (['JUMBO BAG VINTAGE LEAF'])
# 11  (['JUMBO BAG DOILEY PATTERNS' 'JUMBO BAG VINTA...
# 12                      (['JUMBO BAG RED RETROSPOT'])
# 13                      (['JUMBO BAG RED RETROSPOT'])
# 14            (['JUMBO SHOPPER VINTAGE RED PAISLEY'])
# 15                       (['JUMBO STORAGE BAG SUKI'])
# ...

# %%
# Concatenate all the antecedents and consequents
all_items = []
for index, row in cleaned_rules.iterrows():
    all_items.extend(row['antecedents'])
    all_items.extend(row['consequents'])

# Count the occurrence of each item
from collections import Counter
item_counts = Counter(all_items)

# Get the maximum occurring item
max_item = max(item_counts, key=item_counts.get)

# Print the maximum occurring item and its count
print(f"The maximum occurring item is '{max_item}' with a count of {item_counts[max_item]}")
# Out:
# The maximum occurring item is '['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPOTTY']' with a count of 9

# %%
rules.describe()
# Out:
#        antecedent support  consequent support    support  confidence  \
# count           88.000000           88.000000  88.000000   88.000000
# mean             0.053786            0.053786   0.023878    0.484691
# std              0.016852            0.016852   0.002445    0.147873
# min              0.023691            0.023691   0.020322    0.219484
# 25%              0.042545            0.042545   0.021938    0.399477
# 50%              0.052489            0.052489   0.023392    0.450366
# 75%              0.057542            0.057542   0.025171    0.562421
# max              0.107477            0.107477   0.029667    0.894495
#
#             lift   leverage  conviction
# count  88.000000  88.000000   88.000000
# mean   10.086562   0.020987    2.112014
# std     5.340270   0.002521    1.159574
# min     3.792523   0.016845    1.233099
# 25%     6.775277   0.019562    1.577928
# 50%     7.711898   0.020477    1.712148
# 75%    12.130607   0.022342    2.201559
# ...

# %%
rules.isnull().sum()
# Out:
# antecedents           0
# consequents           0
# antecedent support    0
# consequent support    0
# support               0
# confidence            0
# lift                  0
# leverage              0
# conviction            0
# dtype: int64

# %% [markdown]
# Support: It is the frequency of occurrence of a specific itemset in the dataset. It represents the popularity of an itemset in the dataset. High support indicates that the itemset occurs frequently and is significant
#
# Confidence: It measures the conditional probability of finding the consequent in a transaction given that the antecedent is present. It helps us to identify the rules that are specific to the selected country and have a high likelihood of occurring.
#
# Lift: It measures the strength of association between the antecedent and consequent. It helps us to identify the rules that have a high impact on the occurrence of the consequent given the presence of the antecedent

# %%
rules.max()
# Out:
# antecedents                       (['GREEN REGENCY TEACUP AND SAUCER'])
# consequents           (['ROSES REGENCY TEACUP AND SAUCER '], ['PINK ...
# antecedent support                                             0.107477
# consequent support                                             0.107477
# support                                                        0.029667
# confidence                                                     0.894495
# lift                                                          23.861886
# leverage                                                       0.027798
# conviction                                                     9.122388
# dtype: object

# %%
# The number of rules
cleaned_rules.shape[0]
# Out:
# 44

# %%
# Show confidence distribution
plt.hist(cleaned_rules['confidence'])
plt.show()

# %%
#show confidence distribution
plt.hist(cleaned_rules['support'])
plt.show()

# %%
top_10_countries = df['Country'].value_counts().head(10)
print(top_10_countries)
# Out:
# United Kingdom    495478
# Germany             9495
# France              8557
# EIRE                8196
# Spain               2533
# Netherlands         2371
# Belgium             2069
# Switzerland         2002
# Portugal            1519
# Australia           1259
# Name: Country, dtype: int64

# %% [markdown]
# 1st country - Netherlands

# %%
# Build the Apriori model
rep_items_nl = apriori(df_itms_togthr_nl, min_support= 0.1,use_colnames=True)
rep_items_nl.head()
# Out:
#     support                               itemsets
# 0  0.106383   (['72 SWEETHEART FAIRY CAKE CASES'])
# 1  0.127660                 (['CARD DOLLY GIRL '])
# 2  0.117021      (['CHARLOTTE BAG PINK POLKADOT'])
# 3  0.117021        (['CHARLOTTE BAG SUKI DESIGN'])
# 4  0.138298  (['CHILDRENS APRON SPACEBOY DESIGN'])

# %%
# Generate the association rules dataframe
rules_nl = association_rules(rep_items_nl, metric = "confidence")
rules_nl
# Out:
#                                           antecedents  \
# 0                          (['DOLLY GIRL LUNCH BOX'])
# 1                    (['LUNCH BAG SPACEBOY DESIGN '])
# 2   (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 3                (['PACK OF 60 SPACEBOY CAKE CASES'])
# 4                      (['PLASTERS IN TIN SPACEBOY'])
# 5                      (['PLASTERS IN TIN SPACEBOY'])
# 6              (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 7                   (['RED RETROSPOT CHARLOTTE BAG'])
# 8                 (['RED TOADSTOOL LED NIGHT LIGHT'])
# 9            (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 10  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 11  (['SPACEBOY LUNCH BOX '], ['ROUND SNACK BOXES ...
# 12  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 13  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 14  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 15  (['STRAWBERRY LUNCH BOX WITH CUTLERY'], ['SPAC...
# ...

# %% [markdown]
# If we don't mention the min_threshold parameter in the association rules function, it will use the default value of 0.8 for the confidence metric. This means that the function will only return association rules with a confidence level of 0.8 or higher.

# %% [markdown]
# Explanation of the above code :
# For a specific country, we used the metric 'confidence' because we set a higher minimum threshold value of 0.6, which means that we only consider the rules with a high level of confidence. Confidence measures the conditional probability of finding the consequent in a transaction given that the antecedent is present. Therefore, it helps us to identify the rules that are specific to the selected country and have a high likelihood of occurring.

# %%
# Create a copy of the rules dataframe
cleaned_rules_nl = rules_nl.copy()

# Loop through each rule
for i, rule_nl in rules_nl.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules_nl['antecedents'].isin([rule_nl['consequents']]) & cleaned_rules_nl['consequents'].isin([rule_nl['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules_nl = cleaned_rules_nl.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules_nl = cleaned_rules_nl.reset_index(drop=True)

# Print the cleaned rules dataframe
print(cleaned_rules_nl)
# Out:
#                                           antecedents  \
# 0                          (['DOLLY GIRL LUNCH BOX'])
# 1                    (['LUNCH BAG SPACEBOY DESIGN '])
# 2   (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 3                (['PACK OF 60 SPACEBOY CAKE CASES'])
# 4                      (['PLASTERS IN TIN SPACEBOY'])
# 5                      (['PLASTERS IN TIN SPACEBOY'])
# 6              (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 7                   (['RED RETROSPOT CHARLOTTE BAG'])
# 8                 (['RED TOADSTOOL LED NIGHT LIGHT'])
# 9            (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 10  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 11  (['SPACEBOY LUNCH BOX '], ['ROUND SNACK BOXES ...
# 12  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 13  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 14  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 15  (['STRAWBERRY LUNCH BOX WITH CUTLERY'], ['SPAC...
# ...

# %%
cleaned_rules_nl = pd.DataFrame(data=cleaned_rules_nl)
cleaned_rules_nl
# Out:
#                                           antecedents  \
# 0                          (['DOLLY GIRL LUNCH BOX'])
# 1                    (['LUNCH BAG SPACEBOY DESIGN '])
# 2   (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 3                (['PACK OF 60 SPACEBOY CAKE CASES'])
# 4                      (['PLASTERS IN TIN SPACEBOY'])
# 5                      (['PLASTERS IN TIN SPACEBOY'])
# 6              (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 7                   (['RED RETROSPOT CHARLOTTE BAG'])
# 8                 (['RED TOADSTOOL LED NIGHT LIGHT'])
# 9            (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 10  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 11  (['SPACEBOY LUNCH BOX '], ['ROUND SNACK BOXES ...
# 12  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 13  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 14  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 15  (['STRAWBERRY LUNCH BOX WITH CUTLERY'], ['SPAC...
# ...

# %%
list(cleaned_rules_nl["antecedents"][0])[0]                                 #list function: convert sets to list, used to get 1st item in antecedents
# Out:
# "['DOLLY GIRL LUNCH BOX']"

# %%
nl_df["Description"].unique()
# Out:
# array(["['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM HANGING HEART T-LIGHT HOLDER']",
#        "['CREAM CUPID HEARTS COAT HANGER']",
#        "['SET 7 BABUSHKA NESTING BOXES']",
#        "['ASSORTED COLOUR BIRD ORNAMENT']",
#        '["POPPY\'S PLAYHOUSE BEDROOM "]',
#        '["POPPY\'S PLAYHOUSE KITCHEN"]',
#        "['FELTCRAFT PRINCESS CHARLOTTE DOLL']",
#        "['BOX OF VINTAGE ALPHABET BLOCKS']", "['DOORMAT NEW ENGLAND']",
#        "['JAM MAKING SET WITH JARS']", "['ALARM CLOCK BAKELIKE PINK']",
#        "['ALARM CLOCK BAKELIKE RED ']", "['ALARM CLOCK BAKELIKE GREEN']",
#        "['VINTAGE HEADS AND TAILS CARD GAME ']",
#        "['SET/2 RED RETROSPOT TEA TOWELS ']",
#        "['ROUND SNACK BOXES SET OF4 WOODLAND ']",
#        "['SPACEBOY LUNCH BOX ']", "['LUNCH BOX I LOVE LONDON']",
#        "['CIRCUS PARADE LUNCH BOX ']",
#        "['CHARLOTTE BAG DOLLY GIRL DESIGN']",
#        "['RED TOADSTOOL LED NIGHT LIGHT']",
# ...

# %%
# Concatenate all the antecedents and consequents
all_items = []
for index, row in cleaned_rules_nl.iterrows():
    all_items.extend(row['antecedents'])
    all_items.extend(row['consequents'])

# Count the occurrence of each item
from collections import Counter
item_counts = Counter(all_items)

# Get the maximum occurring item
max_item = max(item_counts, key=item_counts.get)

# Print the maximum occurring item and its count
print(f"The maximum occurring item is '{max_item}' with a count of {item_counts[max_item]}")
# Out:
# The maximum occurring item is '['SPACEBOY LUNCH BOX ']' with a count of 20

# %%
import pandas as pd
from collections import Counter

# Count the occurrences of each item in all_items
item_counts = Counter(all_items)

# Create a DataFrame from the item_counts dictionary
df_item_counts = pd.DataFrame.from_dict(item_counts, orient='index', columns=['count'])

# Print the DataFrame

df_item_counts = pd.DataFrame(data=df_item_counts)
df_item_counts
# Out:
#                                                     count
# ['DOLLY GIRL LUNCH BOX']                               15
# ['SPACEBOY LUNCH BOX ']                                20
# ['LUNCH BAG SPACEBOY DESIGN ']                          1
# ['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DESI...      1
# ['ROUND SNACK BOXES SET OF4 WOODLAND ']                19
# ['PACK OF 60 SPACEBOY CAKE CASES']                      1
# ['PLASTERS IN TIN SPACEBOY']                            5
# ['PLASTERS IN TIN WOODLAND ANIMALS']                    1
# ['RED RETROSPOT CHARLOTTE BAG']                         1
# ['RED TOADSTOOL LED NIGHT LIGHT']                       1
# ['ROUND SNACK BOXES SET OF 4 FRUITS ']                 10
# ['STRAWBERRY LUNCH BOX WITH CUTLERY']                   2
# ['WOODLAND CHARLOTTE BAG']                              2

# %%
''' So I am keeping the items above 30% as majority i.e my threshold is 6 items '''
import pandas as pd

# Convert all_items list to a pandas Series
all_items_series = pd.Series(all_items)

# Set the threshold
threshold = 6

# Count the frequency of each item
item_counts = all_items_series.value_counts()

# Get the majority and minority items
majority_items = item_counts[item_counts >= threshold].index.tolist()
minority_items = item_counts[item_counts < threshold].index.tolist()

# Print the results
print("Majority items:", majority_items)
print("Minority items:", minority_items)
# Out:
# Majority items: ["['SPACEBOY LUNCH BOX ']", "['ROUND SNACK BOXES SET OF4 WOODLAND ']", "['DOLLY GIRL LUNCH BOX']", "['ROUND SNACK BOXES SET OF 4 FRUITS ']"]
# Minority items: ["['PLASTERS IN TIN SPACEBOY']", "['STRAWBERRY LUNCH BOX WITH CUTLERY']", "['WOODLAND CHARLOTTE BAG']", "['LUNCH BAG SPACEBOY DESIGN ']", "['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DESIGN ']", "['PACK OF 60 SPACEBOY CAKE CASES']", "['PLASTERS IN TIN WOODLAND ANIMALS']", "['RED RETROSPOT CHARLOTTE BAG']", "['RED TOADSTOOL LED NIGHT LIGHT']"]

# %%
# Create a dictionary to store the counts of minority items
minority_counts = {}
for item in minority_items:
    count = 0
    for index, row in cleaned_rules_nl.iterrows():
        # Check if the minority item is a subset of the itemset
        if set(item.split(", ")) <= set(row['antecedents']) | set(row['consequents']):
            count += 1
    minority_counts[item] = count

# Create a dataframe from the minority_counts dictionary
minority_counts_df = pd.DataFrame.from_dict(minority_counts, orient='index', columns=['count'])
minority_counts_df.index.name = 'item'
minority_counts_df.reset_index(inplace=True)

# Sort the dataframe by count in descending order
minority_counts_df.sort_values('count', ascending=False, inplace=True)

# Print the dataframe
minority_counts_df = pd.DataFrame(data=minority_counts_df)
minority_counts_df
# Out:
#                                                 item  count
# 0                       ['PLASTERS IN TIN SPACEBOY']      5
# 1              ['STRAWBERRY LUNCH BOX WITH CUTLERY']      2
# 2                         ['WOODLAND CHARLOTTE BAG']      2
# 3                     ['LUNCH BAG SPACEBOY DESIGN ']      1
# 4  ['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DES...      1
# 5                 ['PACK OF 60 SPACEBOY CAKE CASES']      1
# 6               ['PLASTERS IN TIN WOODLAND ANIMALS']      1
# 7                    ['RED RETROSPOT CHARLOTTE BAG']      1
# 8                  ['RED TOADSTOOL LED NIGHT LIGHT']      1

# %%
# Create a dictionary to store the counts of majority items
majority_counts = {}
for item in majority_items:
    count = 0
    for index, row in cleaned_rules_nl.iterrows():
        # Check if the majority item is a subset of the itemset
        if set(item.split(", ")) <= set(row['antecedents']) | set(row['consequents']):
            count += 1
    majority_counts[item] = count

# Create a dataframe from the majority_counts dictionary
majority_counts_df = pd.DataFrame.from_dict(majority_counts, orient='index', columns=['count'])
majority_counts_df.index.name = 'item'
majority_counts_df.reset_index(inplace=True)

# Sort the dataframe by count in descending order
majority_counts_df.sort_values('count', ascending=False, inplace=True)

majority_counts_df = pd.DataFrame.from_dict(majority_counts, orient='index', columns=['Count'])


majority_counts_df = pd.DataFrame(data=majority_counts_df)
majority_counts_df
# Out:
#                                          Count
# ['SPACEBOY LUNCH BOX ']                     20
# ['ROUND SNACK BOXES SET OF4 WOODLAND ']     19
# ['DOLLY GIRL LUNCH BOX']                    15
# ['ROUND SNACK BOXES SET OF 4 FRUITS ']      10

# %%
antecedent_consequent = cleaned_rules_nl.loc[:, ['antecedents', 'consequents']]
antecedent_consequent = pd.DataFrame(data=antecedent_consequent)
antecedent_consequent
# Out:
#                                           antecedents  \
# 0                          (['DOLLY GIRL LUNCH BOX'])
# 1                    (['LUNCH BAG SPACEBOY DESIGN '])
# 2   (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 3                (['PACK OF 60 SPACEBOY CAKE CASES'])
# 4                      (['PLASTERS IN TIN SPACEBOY'])
# 5                      (['PLASTERS IN TIN SPACEBOY'])
# 6              (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 7                   (['RED RETROSPOT CHARLOTTE BAG'])
# 8                 (['RED TOADSTOOL LED NIGHT LIGHT'])
# 9            (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 10  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 11  (['SPACEBOY LUNCH BOX '], ['ROUND SNACK BOXES ...
# 12  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 13  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 14  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 15  (['STRAWBERRY LUNCH BOX WITH CUTLERY'], ['SPAC...
# ...

# %%
# Get the transactions dataframe with 'DOLLY GIRL LUNCH BOX' in either antecedents or consequents
desc_value = 'DOLLY GIRL LUNCH BOX'
mask = cleaned_rules_nl['antecedents'].astype(str).str.contains(desc_value) | cleaned_rules_nl['consequents'].astype(str).str.contains(desc_value)
transactions_filtered = antecedent_consequent[mask]

# Display the filtered transactions dataframe In dataframe
transactions_filtered = pd.DataFrame(data=transactions_filtered)
transactions_filtered
# Out:
#                                           antecedents  \
# 0                          (['DOLLY GIRL LUNCH BOX'])
# 10  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 11  (['SPACEBOY LUNCH BOX '], ['ROUND SNACK BOXES ...
# 12  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 13  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 14  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 15  (['STRAWBERRY LUNCH BOX WITH CUTLERY'], ['SPAC...
# 16  (['STRAWBERRY LUNCH BOX WITH CUTLERY'], ['DOLL...
# 17  (['WOODLAND CHARLOTTE BAG'], ['DOLLY GIRL LUNC...
# 18  (['SPACEBOY LUNCH BOX '], ['WOODLAND CHARLOTTE...
# 23  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 24  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 25  (['SPACEBOY LUNCH BOX '], ['DOLLY GIRL LUNCH B...
# 26  (['SPACEBOY LUNCH BOX '], ['ROUND SNACK BOXES ...
# 27  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
#
#                                           consequents
# ...

# %% [markdown]
# There are 15 transactions with the above description

# %%
# The number of rules
cleaned_rules_nl.shape[0]
# Out:
# 28

# %%
high_confidance_nl = cleaned_rules_nl[cleaned_rules_nl['confidence'] > 0.75]
high_confidance_nl [['antecedents', 'consequents']]
# Out:
#                                           antecedents  \
# 0                          (['DOLLY GIRL LUNCH BOX'])
# 1                    (['LUNCH BAG SPACEBOY DESIGN '])
# 2   (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 3                (['PACK OF 60 SPACEBOY CAKE CASES'])
# 4                      (['PLASTERS IN TIN SPACEBOY'])
# 5                      (['PLASTERS IN TIN SPACEBOY'])
# 6              (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 7                   (['RED RETROSPOT CHARLOTTE BAG'])
# 8                 (['RED TOADSTOOL LED NIGHT LIGHT'])
# 9            (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 10  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 11  (['SPACEBOY LUNCH BOX '], ['ROUND SNACK BOXES ...
# 12  (['DOLLY GIRL LUNCH BOX'], ['ROUND SNACK BOXES...
# 13  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 14  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 15  (['STRAWBERRY LUNCH BOX WITH CUTLERY'], ['SPAC...
# ...

# %% [markdown]
# 2nd Country - United Kingdom

# %%
# Build the Apriori model
rep_items_uk = apriori(df_itms_togthr_uk, min_support = 0.1, use_colnames = True)
rep_items_uk.head()
# Out:
#     support                                           itemsets
# 0  0.114053  (['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM ...

# %% [markdown]
# The minimum support value can affect the generation of association rules.
#
# Higher minimum support value will lead to fewer frequent itemsets, which in turn will lead to fewer association rules being generated.
#
# Lower minimum support value will result in more frequent itemsets and potentially more association rules.

# %%
# Generate the association rules dataframe
rules_uk = association_rules(rep_items_uk, metric = "confidence")
rules_uk
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
# Create a copy of the rules dataframe
cleaned_rules_uk = rules_uk.copy()

# Loop through each rule
for i, rule in rules_uk.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules_uk['antecedents'].isin([rule['consequents']]) & cleaned_rules_uk['consequents'].isin([rule['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules_uk = cleaned_rules_uk.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules_uk = cleaned_rules_uk.reset_index(drop=True)

# Print the cleaned rules dataframe
print(cleaned_rules_uk)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
cleaned_rules_uk = pd.DataFrame(data=cleaned_rules_uk)
cleaned_rules_uk
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# 3rd Country - Spain

# %%
# Build the Apriori model
rep_items_spain = apriori(df_itms_togthr_spain, min_support = 0.1, use_colnames = True)
rep_items_spain.head()
# Out:
#     support                                   itemsets
# 0  0.170455               (['6 RIBBONS RUSTIC CHARM'])
# 1  0.136364        (['ASSORTED COLOUR BIRD ORNAMENT'])
# 2  0.113636  (['CLASSIC METAL BIRDCAGE PLANT HOLDER'])
# 3  0.102273                 (['DOLLY GIRL LUNCH BOX'])
# 4  0.159091             (['JAM MAKING SET WITH JARS'])

# %%
# Generate the association rules dataframe
rules_spain = association_rules(rep_items_spain, metric = "confidence", min_threshold = 0.6)
rules_spain
# Out:
#                            antecedents                          consequents  \
# 0         (['6 RIBBONS RUSTIC CHARM'])  (['ASSORTED COLOUR BIRD ORNAMENT'])
# 1  (['ASSORTED COLOUR BIRD ORNAMENT'])         (['6 RIBBONS RUSTIC CHARM'])
#
#    antecedent support  consequent support   support  confidence  lift  \
# 0            0.170455            0.136364  0.102273        0.60   4.4
# 1            0.136364            0.170455  0.102273        0.75   4.4
#
#    leverage  conviction
# 0  0.079029    2.159091
# 1  0.079029    3.318182

# %%
# Create a copy of the rules dataframe
cleaned_rules_spain = rules_spain.copy()

# Loop through each rule
for i, rule in rules_spain.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules_spain['antecedents'].isin([rule['consequents']]) & cleaned_rules_spain['consequents'].isin([rule['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules_spain = cleaned_rules_spain.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules_spain = cleaned_rules_spain.reset_index(drop=True)

# Print the cleaned rules dataframe
print(cleaned_rules_spain)
# Out:
#                            antecedents                   consequents  \
# 0  (['ASSORTED COLOUR BIRD ORNAMENT'])  (['6 RIBBONS RUSTIC CHARM'])
#
#    antecedent support  consequent support   support  confidence  lift  \
# 0            0.136364            0.170455  0.102273        0.75   4.4
#
#    leverage  conviction
# 0  0.079029    3.318182

# %%
cleaned_rules_spain = pd.DataFrame(data=cleaned_rules_spain)
cleaned_rules_spain
# Out:
#                            antecedents                   consequents  \
# 0  (['ASSORTED COLOUR BIRD ORNAMENT'])  (['6 RIBBONS RUSTIC CHARM'])
#
#    antecedent support  consequent support   support  confidence  lift  \
# 0            0.136364            0.170455  0.102273        0.75   4.4
#
#    leverage  conviction
# 0  0.079029    3.318182

# %%
# The number of rules
cleaned_rules_spain.shape[0]
# Out:
# 1

# %%
high_confidance_spain = cleaned_rules_spain[cleaned_rules_spain['confidence'] > 0.75]
high_confidance_spain [['antecedents', 'consequents']]
# Out:
#                            antecedents                   consequents
# 0  (['ASSORTED COLOUR BIRD ORNAMENT'])  (['6 RIBBONS RUSTIC CHARM'])

# %% [markdown]
# 4th Country - France

# %%
# Build the Apriori model
rep_items_france = apriori(df_itms_togthr_france, min_support = 0.1, use_colnames = True)
rep_items_france
# Out:
#      support                                           itemsets
# 0   0.100264                   (['ALARM CLOCK BAKELIKE GREEN'])
# 1   0.105541                    (['ALARM CLOCK BAKELIKE PINK'])
# 2   0.102902                         (['DOLLY GIRL LUNCH BOX'])
# 3   0.100264                      (['JUMBO BAG RED RETROSPOT'])
# 4   0.129288                       (['LUNCH BAG APPLE DESIGN'])
# 5   0.158311  (['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPO...
# 6   0.124011                   (['LUNCH BAG SPACEBOY DESIGN '])
# 7   0.121372                           (['LUNCH BAG WOODLAND'])
# 8   0.147757            (['LUNCH BOX WITH CUTLERY RETROSPOT '])
# 9   0.108179                      (['MINI PAINT SET VINTAGE '])
# 10  0.105541              (['PACK OF 72 RETROSPOT CAKE CASES'])
# 11  0.174142               (['PLASTERS IN TIN CIRCUS PARADE '])
# 12  0.139842                     (['PLASTERS IN TIN SPACEBOY'])
# 13  0.176781             (['PLASTERS IN TIN WOODLAND ANIMALS'])
# ...

# %%
# Generate the association rules dataframe
rules_france = association_rules(rep_items_france, metric = "confidence", min_threshold = 0.6)
rules_france
# Out:
#                                           antecedents  \
# 0                (['PLASTERS IN TIN CIRCUS PARADE '])
# 1                      (['PLASTERS IN TIN SPACEBOY'])
# 2              (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 3                   (['SET/6 RED SPOTTY PAPER CUPS'])
# 4           (['SET/20 RED RETROSPOT PAPER NAPKINS '])
# 5                 (['SET/6 RED SPOTTY PAPER PLATES'])
# 6           (['SET/20 RED RETROSPOT PAPER NAPKINS '])
# 7                   (['SET/6 RED SPOTTY PAPER CUPS'])
# 8                 (['SET/6 RED SPOTTY PAPER PLATES'])
# 9   (['SET/6 RED SPOTTY PAPER CUPS'], ['SET/6 RED ...
# 10  (['SET/6 RED SPOTTY PAPER CUPS'], ['SET/20 RED...
# 11  (['SET/6 RED SPOTTY PAPER PLATES'], ['SET/20 R...
# 12                  (['SET/6 RED SPOTTY PAPER CUPS'])
# 13                (['SET/6 RED SPOTTY PAPER PLATES'])
# 14          (['SET/20 RED RETROSPOT PAPER NAPKINS '])
#
#                                           consequents  antecedent support  \
# ...

# %%
# Generate the association rules dataframe
rules_france = association_rules(rep_items_france, metric="confidence", min_threshold=0.6)

# Create a copy of the rules dataframe
cleaned_rules_france = rules_france.copy()

# Loop through each rule
for i, rule_france in rules_france.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules_france['antecedents'].isin([rule_france['consequents']]) & cleaned_rules_france['consequents'].isin([rule_france['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules_france = cleaned_rules_france.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules_france = cleaned_rules_france.reset_index(drop=True)

# Print the cleaned rules dataframe
cleaned_rules_france = pd.DataFrame(data=cleaned_rules_france)
cleaned_rules_france
# Out:
#                                  antecedents  \
# 0       (['PLASTERS IN TIN CIRCUS PARADE '])
# 1     (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 2  (['SET/20 RED RETROSPOT PAPER NAPKINS '])
# 3  (['SET/20 RED RETROSPOT PAPER NAPKINS '])
# 4        (['SET/6 RED SPOTTY PAPER PLATES'])
# 5          (['SET/6 RED SPOTTY PAPER CUPS'])
# 6        (['SET/6 RED SPOTTY PAPER PLATES'])
# 7  (['SET/20 RED RETROSPOT PAPER NAPKINS '])
#
#                                          consequents  antecedent support  \
# 0             (['PLASTERS IN TIN WOODLAND ANIMALS'])            0.174142
# 1                     (['PLASTERS IN TIN SPACEBOY'])            0.176781
# 2                  (['SET/6 RED SPOTTY PAPER CUPS'])            0.137203
# 3                (['SET/6 RED SPOTTY PAPER PLATES'])            0.137203
# 4                  (['SET/6 RED SPOTTY PAPER CUPS'])            0.131926
# 5  (['SET/6 RED SPOTTY PAPER PLATES'], ['SET/20 R...            0.142480
# ...

# %%
cleaned_rules_france = pd.DataFrame(data=cleaned_rules_france)
cleaned_rules_france
# Out:
#                                  antecedents  \
# 0       (['PLASTERS IN TIN CIRCUS PARADE '])
# 1     (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 2  (['SET/20 RED RETROSPOT PAPER NAPKINS '])
# 3  (['SET/20 RED RETROSPOT PAPER NAPKINS '])
# 4        (['SET/6 RED SPOTTY PAPER PLATES'])
# 5          (['SET/6 RED SPOTTY PAPER CUPS'])
# 6        (['SET/6 RED SPOTTY PAPER PLATES'])
# 7  (['SET/20 RED RETROSPOT PAPER NAPKINS '])
#
#                                          consequents  antecedent support  \
# 0             (['PLASTERS IN TIN WOODLAND ANIMALS'])            0.174142
# 1                     (['PLASTERS IN TIN SPACEBOY'])            0.176781
# 2                  (['SET/6 RED SPOTTY PAPER CUPS'])            0.137203
# 3                (['SET/6 RED SPOTTY PAPER PLATES'])            0.137203
# 4                  (['SET/6 RED SPOTTY PAPER CUPS'])            0.131926
# 5  (['SET/6 RED SPOTTY PAPER PLATES'], ['SET/20 R...            0.142480
# ...

# %%
# The number of rules
cleaned_rules_france.shape[0]
# Out:
# 8

# %%
high_confidance_france = cleaned_rules_france[rules_france['confidence'] > 0.75]
high_confidance_france [['antecedents', 'consequents']]
# Out:
# <ipython-input-395-cdb7c64d049a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_confidance_france = cleaned_rules_france[rules_france['confidence'] > 0.75]
#                                  antecedents  \
# 1     (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 4        (['SET/6 RED SPOTTY PAPER PLATES'])
# 5          (['SET/6 RED SPOTTY PAPER CUPS'])
# 6        (['SET/6 RED SPOTTY PAPER PLATES'])
# 7  (['SET/20 RED RETROSPOT PAPER NAPKINS '])
#
#                                          consequents
# 1                     (['PLASTERS IN TIN SPACEBOY'])
# 4                  (['SET/6 RED SPOTTY PAPER CUPS'])
# 5  (['SET/6 RED SPOTTY PAPER PLATES'], ['SET/20 R...
# 6  (['SET/6 RED SPOTTY PAPER CUPS'], ['SET/20 RED...
# 7  (['SET/6 RED SPOTTY PAPER CUPS'], ['SET/6 RED ...

# %% [markdown]
# 5th Country - Germany

# %%
# Build the Apriori model
rep_items_ger = apriori(df_itms_togthr_ger, min_support = 0.1, use_colnames = True)
rep_items_ger
# Out:
#      support                                           itemsets
# 0   0.106095                       (['6 RIBBONS RUSTIC CHARM'])
# 1   0.103837                   (['JUMBO BAG WOODLAND ANIMALS'])
# 2   0.119639               (['PLASTERS IN TIN CIRCUS PARADE '])
# 3   0.110609                     (['PLASTERS IN TIN SPACEBOY'])
# 4   0.142212             (['PLASTERS IN TIN WOODLAND ANIMALS'])
# 5   0.142212                     (['REGENCY CAKESTAND 3 TIER'])
# 6   0.162528           (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 7   0.252822          (['ROUND SNACK BOXES SET OF4 WOODLAND '])
# 8   0.106095                          (['SPACEBOY LUNCH BOX '])
# 9   0.130926                       (['WOODLAND CHARLOTTE BAG'])
# 10  0.135440  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['RO...

# %%
# Generate the association rules dataframe
rules_ger = association_rules(rep_items_ger, metric = "confidence", min_threshold = 0.6)
rules_ger
# Out:
#                                 antecedents  \
# 0  (['ROUND SNACK BOXES SET OF 4 FRUITS '])
#
#                                  consequents  antecedent support  \
# 0  (['ROUND SNACK BOXES SET OF4 WOODLAND '])            0.162528
#
#    consequent support  support  confidence      lift  leverage  conviction
# 0            0.252822  0.13544    0.833333  3.296131   0.09435     4.48307

# %%
# The number of rules
rules_ger.shape[0]
# Out:
# 1

# %%
high_confidance_ger = rules_ger[rules_ger['confidence'] > 0.75]
high_confidance_ger [['antecedents', 'consequents']]
# Out:
#                                 antecedents  \
# 0  (['ROUND SNACK BOXES SET OF 4 FRUITS '])
#
#                                  consequents
# 0  (['ROUND SNACK BOXES SET OF4 WOODLAND '])

# %% [markdown]
# 6th Country - EIRE

# %%
# Build the Apriori model
rep_items_eire = apriori(df_itms_togthr_eire, min_support = 0.1, use_colnames = True)
rep_items_eire
# Out:
#      support                                           itemsets
# 0   0.132812              (['GREEN REGENCY TEACUP AND SAUCER'])
# 1   0.113281                       (['JAM MAKING SET PRINTED'])
# 2   0.121094                     (['JAM MAKING SET WITH JARS'])
# 3   0.109375              (['PACK OF 72 RETROSPOT CAKE CASES'])
# 4   0.109375               (['PINK REGENCY TEACUP AND SAUCER'])
# 5   0.246094                     (['REGENCY CAKESTAND 3 TIER'])
# 6   0.171875             (['ROSES REGENCY TEACUP AND SAUCER '])
# 7   0.105469            (['SET OF 3 CAKE TINS PANTRY DESIGN '])
# 8   0.132812                   (['SET OF 3 REGENCY CAKE TINS'])
# 9   0.132812        (['SMALL POPCORN HOLDER' 'POPCORN HOLDER'])
# 10  0.148438                           (['VINTAGE SNAP CARDS'])
# 11  0.156250  (['WHITE HANGING HEART T-LIGHT HOLDER' 'CREAM ...
# 12  0.101562  (['PINK REGENCY TEACUP AND SAUCER'], ['GREEN R...
# 13  0.121094  (['ROSES REGENCY TEACUP AND SAUCER '], ['GREEN...
# ...

# %%
# Generate the association rules dataframe
rules_eire = association_rules(rep_items_eire, metric = "confidence", min_threshold = 0.6)
rules_eire
# Out:
#                               antecedents  \
# 0    (['PINK REGENCY TEACUP AND SAUCER'])
# 1   (['GREEN REGENCY TEACUP AND SAUCER'])
# 2  (['ROSES REGENCY TEACUP AND SAUCER '])
# 3   (['GREEN REGENCY TEACUP AND SAUCER'])
# 4  (['ROSES REGENCY TEACUP AND SAUCER '])
# 5    (['PINK REGENCY TEACUP AND SAUCER'])
# 6  (['ROSES REGENCY TEACUP AND SAUCER '])
#
#                               consequents  antecedent support  \
# 0   (['GREEN REGENCY TEACUP AND SAUCER'])            0.109375
# 1    (['PINK REGENCY TEACUP AND SAUCER'])            0.132812
# 2   (['GREEN REGENCY TEACUP AND SAUCER'])            0.171875
# 3  (['ROSES REGENCY TEACUP AND SAUCER '])            0.132812
# 4    (['PINK REGENCY TEACUP AND SAUCER'])            0.171875
# 5  (['ROSES REGENCY TEACUP AND SAUCER '])            0.109375
# 6          (['REGENCY CAKESTAND 3 TIER'])            0.171875
#
#    consequent support   support  confidence      lift  leverage  conviction
# ...

# %%
# Read the data into a DataFrame
import pandas as pd

data = {
    'antecedents': [(['PINK REGENCY TEACUP AND SAUCER']),
                    (['GREEN REGENCY TEACUP AND SAUCER']),
                    (['ROSES REGENCY TEACUP AND SAUCER ']),
                    (['GREEN REGENCY TEACUP AND SAUCER']),
                    (['PINK REGENCY TEACUP AND SAUCER']),
                    (['ROSES REGENCY TEACUP AND SAUCER ']),
                    (['ROSES REGENCY TEACUP AND SAUCER '])],
    
    'consequents': [(['GREEN REGENCY TEACUP AND SAUCER']),
                    (['PINK REGENCY TEACUP AND SAUCER']),
                    (['GREEN REGENCY TEACUP AND SAUCER']),
                    (['ROSES REGENCY TEACUP AND SAUCER ']),
                    (['ROSES REGENCY TEACUP AND SAUCER ']),
                    (['PINK REGENCY TEACUP AND SAUCER']),
                    (['REGENCY CAKESTAND 3 TIER'])],
    
    'antecedent support': [0.109375, 0.132812, 0.171875, 0.132812, 0.109375, 0.171875, 0.171875],
    
    'consequent support': [0.132812, 0.109375, 0.132812, 0.171875, 0.171875, 0.109375, 0.246094],
    
    'support': [0.101562, 0.101562, 0.121094, 0.121094, 0.105469, 0.105469, 0.113281],
    
    'confidence': [0.928571, 0.764706, 0.704545, 0.911765, 0.964286, 0.613636, 0.659091],
    
    'lift': [6.991597, 6.991597, 5.304813, 5.304813, 5.610390, 5.610390, 2.678211],
    
    'leverage': [0.087036, 0.087036, 0.098267, 0.098267, 0.086670, 0.086670, 0.070984],
    
    'conviction': [12.140625, 3.785156, 2.935096, 9.385417, 23.187500, 2.305147, 2.211458]
}

df = pd.DataFrame(data)

# Drop 2nd, 4th, 6th rows
df = df.drop([1, 3, 5]).reset_index(drop=True)

# Show resulting DataFrame
print(df)
# Out:
#                           antecedents                         consequents  \
# 0    [PINK REGENCY TEACUP AND SAUCER]   [GREEN REGENCY TEACUP AND SAUCER]
# 1  [ROSES REGENCY TEACUP AND SAUCER ]   [GREEN REGENCY TEACUP AND SAUCER]
# 2    [PINK REGENCY TEACUP AND SAUCER]  [ROSES REGENCY TEACUP AND SAUCER ]
# 3  [ROSES REGENCY TEACUP AND SAUCER ]          [REGENCY CAKESTAND 3 TIER]
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.109375            0.132812  0.101562    0.928571  6.991597
# 1            0.171875            0.132812  0.121094    0.704545  5.304813
# 2            0.109375            0.171875  0.105469    0.964286  5.610390
# 3            0.171875            0.246094  0.113281    0.659091  2.678211
#
#    leverage  conviction
# 0  0.087036   12.140625
# 1  0.098267    2.935096
# 2  0.086670   23.187500
# 3  0.070984    2.211458

# %%
df = pd.DataFrame(data=df)
df
# Out:
#                           antecedents                         consequents  \
# 0    [PINK REGENCY TEACUP AND SAUCER]   [GREEN REGENCY TEACUP AND SAUCER]
# 1  [ROSES REGENCY TEACUP AND SAUCER ]   [GREEN REGENCY TEACUP AND SAUCER]
# 2    [PINK REGENCY TEACUP AND SAUCER]  [ROSES REGENCY TEACUP AND SAUCER ]
# 3  [ROSES REGENCY TEACUP AND SAUCER ]          [REGENCY CAKESTAND 3 TIER]
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.109375            0.132812  0.101562    0.928571  6.991597
# 1            0.171875            0.132812  0.121094    0.704545  5.304813
# 2            0.109375            0.171875  0.105469    0.964286  5.610390
# 3            0.171875            0.246094  0.113281    0.659091  2.678211
#
#    leverage  conviction
# 0  0.087036   12.140625
# 1  0.098267    2.935096
# 2  0.086670   23.187500
# 3  0.070984    2.211458

# %%
# Concatenate all the antecedents and consequents
all_items = []
for index, row in df.iterrows():
    all_items.extend(row['antecedents'])
    all_items.extend(row['consequents'])

# Count the occurrence of each item
from collections import Counter
item_counts = Counter(all_items)

# Get the maximum occurring item
max_item = max(item_counts, key=item_counts.get)

# Print the maximum occurring item and its count
print(f"The maximum occurring item is '{max_item}' with a count of {item_counts[max_item]}")
# Out:
# The maximum occurring item is 'ROSES REGENCY TEACUP AND SAUCER ' with a count of 3

# %%
# The number of rules
df.shape[0]
# Out:
# 4

# %%
high_confidance_france = df[df['confidence'] > 0.75]
high_confidance_france [['antecedents', 'consequents']]
# Out:
#                         antecedents                         consequents
# 0  [PINK REGENCY TEACUP AND SAUCER]   [GREEN REGENCY TEACUP AND SAUCER]
# 2  [PINK REGENCY TEACUP AND SAUCER]  [ROSES REGENCY TEACUP AND SAUCER ]

# %% [markdown]
# 7th Country - Belgium

# %%
# Build the Apriori model
rep_items_bel = apriori(df_itms_togthr_bel, min_support = 0.1, use_colnames = True)
rep_items_bel
# Out:
#      support                                           itemsets
# 0   0.122449                   (['ALARM CLOCK BAKELIKE GREEN'])
# 1   0.132653                    (['ALARM CLOCK BAKELIKE RED '])
# 2   0.102041                  (['CHARLOTTE BAG APPLES DESIGN'])
# 3   0.112245  (['CHILDRENS CUTLERY SPACEBOY ' 'KIDS CUTLERY ...
# 4   0.102041                     (['CIRCUS PARADE LUNCH BOX '])
# 5   0.234694                         (['DOLLY GIRL LUNCH BOX'])
# 6   0.122449                         (['IVORY KITCHEN SCALES'])
# 7   0.102041                      (['JUMBO BAG RED RETROSPOT'])
# 8   0.122449  (['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPO...
# 9   0.112245                   (['LUNCH BAG SPACEBOY DESIGN '])
# 10  0.153061                           (['LUNCH BAG WOODLAND'])
# 11  0.102041            (['LUNCH BOX WITH CUTLERY RETROSPOT '])
# 12  0.102041               (['PACK OF 60 DINOSAUR CAKE CASES'])
# 13  0.122449              (['PACK OF 72 RETROSPOT CAKE CASES'])
# ...

# %%
# Generate the association rules dataframe
rules_bel = association_rules(rep_items_bel, metric = "confidence", min_threshold = 0.6)
rules_bel
# Out:
#                                           antecedents  \
# 0                    (['ALARM CLOCK BAKELIKE GREEN'])
# 1                     (['ALARM CLOCK BAKELIKE RED '])
# 2                          (['DOLLY GIRL LUNCH BOX'])
# 3                           (['SPACEBOY LUNCH BOX '])
# 4                          (['DOLLY GIRL LUNCH BOX'])
# 5                            (['LUNCH BAG WOODLAND'])
# 6            (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 7                           (['SPACEBOY LUNCH BOX '])
# 8   (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 9   (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 10  (['SPACEBOY LUNCH BOX '], ['DOLLY GIRL LUNCH B...
#
#                                   consequents  antecedent support  \
# 0             (['ALARM CLOCK BAKELIKE RED '])            0.122449
# 1            (['ALARM CLOCK BAKELIKE GREEN'])            0.132653
# 2   (['ROUND SNACK BOXES SET OF4 WOODLAND '])            0.234694
# ...

# %%
# Create a copy of the rules dataframe
cleaned_rules_bel = rules_bel.copy()

# Loop through each rule
for i, rule_bel in rules_bel.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules_bel['antecedents'].isin([rule_bel['consequents']]) & cleaned_rules_bel['consequents'].isin([rule_bel['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules_bel = cleaned_rules_bel.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules_bel = cleaned_rules_bel.reset_index(drop=True)

# Print the cleaned rules dataframe
cleaned_rules_bel = pd.DataFrame(data=cleaned_rules_bel)
cleaned_rules_bel
# Out:
#                                          antecedents  \
# 0                    (['ALARM CLOCK BAKELIKE RED '])
# 1                         (['DOLLY GIRL LUNCH BOX'])
# 2                         (['DOLLY GIRL LUNCH BOX'])
# 3                           (['LUNCH BAG WOODLAND'])
# 4           (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 5                          (['SPACEBOY LUNCH BOX '])
# 6  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 7  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['DO...
# 8  (['SPACEBOY LUNCH BOX '], ['DOLLY GIRL LUNCH B...
#
#                                  consequents  antecedent support  \
# 0           (['ALARM CLOCK BAKELIKE GREEN'])            0.132653
# 1  (['ROUND SNACK BOXES SET OF4 WOODLAND '])            0.234694
# 2                  (['SPACEBOY LUNCH BOX '])            0.234694
# 3  (['ROUND SNACK BOXES SET OF4 WOODLAND '])            0.153061
# 4  (['ROUND SNACK BOXES SET OF4 WOODLAND '])            0.224490
# ...

# %%
# Concatenate all the antecedents and consequents
all_items = []
for index, row in cleaned_rules_bel.iterrows():
    all_items.extend(row['antecedents'])
    all_items.extend(row['consequents'])

# Count the occurrence of each item
from collections import Counter
item_counts = Counter(all_items)

# Get the maximum occurring item
max_item = max(item_counts, key=item_counts.get)

# Print the maximum occurring item and its count
print(f"The maximum occurring item is '{max_item}' with a count of {item_counts[max_item]}")
# Out:
# The maximum occurring item is '['ROUND SNACK BOXES SET OF4 WOODLAND ']' with a count of 7

# %%
# The number of rules
cleaned_rules_bel.shape[0]
# Out:
# 9

# %%
high_confidance_bel = cleaned_rules_bel[rules_bel['confidence'] > 0.75]
high_confidance_bel [['antecedents', 'consequents']]
# Out:
# <ipython-input-412-7260218120bc>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_confidance_bel = cleaned_rules_bel[rules_bel['confidence'] > 0.75]
#                                          antecedents  \
# 0                    (['ALARM CLOCK BAKELIKE RED '])
# 1                         (['DOLLY GIRL LUNCH BOX'])
# 3                           (['LUNCH BAG WOODLAND'])
# 4           (['ROUND SNACK BOXES SET OF 4 FRUITS '])
# 5                          (['SPACEBOY LUNCH BOX '])
# 6  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['SP...
# 8  (['SPACEBOY LUNCH BOX '], ['DOLLY GIRL LUNCH B...
#
#                                  consequents
# 0           (['ALARM CLOCK BAKELIKE GREEN'])
# 1  (['ROUND SNACK BOXES SET OF4 WOODLAND '])
# 3  (['ROUND SNACK BOXES SET OF4 WOODLAND '])
# 4  (['ROUND SNACK BOXES SET OF4 WOODLAND '])
# 5  (['ROUND SNACK BOXES SET OF4 WOODLAND '])
# 6                 (['DOLLY GIRL LUNCH BOX'])
# ...

# %% [markdown]
# 8th Country - Switzerland

# %%
# Build the Apriori model
rep_items_switz = apriori(df_itms_togthr_switz, min_support = 0.1, use_colnames = True)
rep_items_switz
# Out:
#       support                                           itemsets
# 0    0.106383                      ([' SPACEBOY BABY GIFT SET'])
# 1    0.106383            (['5 HOOK HANGER RED MAGIC TOADSTOOL'])
# 2    0.106383                (['ASSORTED BOTTLE TOP  MAGNETS '])
# 3    0.106383                (['BAKING SET 9 PIECE RETROSPOT '])
# 4    0.106383                 (['BLACK/BLUE POLKADOT UMBRELLA'])
# ..        ...                                                ...
# 170  0.106383  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['WA...
# 171  0.127660  (['PLASTERS IN TIN SPACEBOY'], ['PLASTERS IN T...
# 172  0.106383  (['SPACEBOY BIRTHDAY CARD'], ['PLASTERS IN TIN...
# 173  0.106383  (['PLASTERS IN TIN SPACEBOY'], ['RED RETROSPOT...
# 174  0.106383  (['RED TOADSTOOL LED NIGHT LIGHT'], ['ROUND SN...
#
# [175 rows x 2 columns]

# %%
# Generate the association rules dataframe
rules_switz = association_rules(rep_items_switz, metric = "confidence", min_threshold = 0.6)
rules_switz
# Out:
#                                            antecedents  \
# 0                        ([' SPACEBOY BABY GIFT SET'])
# 1                             (['BLUE POLKADOT BOWL'])
# 2                             (['RED RETROSPOT BOWL'])
# 3                             (['BLUE POLKADOT BOWL'])
# 4                             (['CARD CIRCUS PARADE'])
# ..                                                 ...
# 226  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['WA...
# 227  (['WATERING CAN PINK BUNNY'], ['WATERING CAN B...
# 228                (['RED TOADSTOOL LED NIGHT LIGHT'])
# 229                      (['WATERING CAN PINK BUNNY'])
# 230                   (['WATERING CAN BLUE ELEPHANT'])
#
#                                            consequents  antecedent support  \
# 0               (['PLASTERS IN TIN WOODLAND ANIMALS'])            0.106383
# 1                             (['RED RETROSPOT BOWL'])            0.127660
# 2                             (['BLUE POLKADOT BOWL'])            0.170213
# ...

# %%
# Create a copy of the rules dataframe
cleaned_rules_switz = rules_switz.copy()

# Loop through each rule
for i, rule_switz in rules_switz.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules_switz['antecedents'].isin([rule_switz['consequents']]) & cleaned_rules_switz['consequents'].isin([rule_switz['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules_switz = cleaned_rules_switz.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules_switz = cleaned_rules_switz.reset_index(drop=True)

# Print the cleaned rules dataframe
print(cleaned_rules_switz)
# Out:
#                                            antecedents  \
# 0                        ([' SPACEBOY BABY GIFT SET'])
# 1                             (['RED RETROSPOT BOWL'])
# 2                             (['BLUE POLKADOT BOWL'])
# 3                             (['CARD CIRCUS PARADE'])
# 4    (['CHILDRENS CUTLERY SPACEBOY ' 'KIDS CUTLERY ...
# ..                                                 ...
# 179  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['WA...
# 180  (['WATERING CAN PINK BUNNY'], ['WATERING CAN B...
# 181                (['RED TOADSTOOL LED NIGHT LIGHT'])
# 182                      (['WATERING CAN PINK BUNNY'])
# 183                   (['WATERING CAN BLUE ELEPHANT'])
#
#                                            consequents  antecedent support  \
# 0               (['PLASTERS IN TIN WOODLAND ANIMALS'])            0.106383
# 1                             (['BLUE POLKADOT BOWL'])            0.170213
# 2             (['SPOTTY BUNTING' 'BUNTING , SPOTTY '])            0.127660
# ...

# %%
cleaned_rules_switz = pd.DataFrame(data=cleaned_rules_switz)
cleaned_rules_switz
# Out:
#                                            antecedents  \
# 0                        ([' SPACEBOY BABY GIFT SET'])
# 1                             (['RED RETROSPOT BOWL'])
# 2                             (['BLUE POLKADOT BOWL'])
# 3                             (['CARD CIRCUS PARADE'])
# 4    (['CHILDRENS CUTLERY SPACEBOY ' 'KIDS CUTLERY ...
# ..                                                 ...
# 179  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['WA...
# 180  (['WATERING CAN PINK BUNNY'], ['WATERING CAN B...
# 181                (['RED TOADSTOOL LED NIGHT LIGHT'])
# 182                      (['WATERING CAN PINK BUNNY'])
# 183                   (['WATERING CAN BLUE ELEPHANT'])
#
#                                            consequents  antecedent support  \
# 0               (['PLASTERS IN TIN WOODLAND ANIMALS'])            0.106383
# 1                             (['BLUE POLKADOT BOWL'])            0.170213
# 2             (['SPOTTY BUNTING' 'BUNTING , SPOTTY '])            0.127660
# ...

# %%
# Concatenate all the antecedents and consequents
all_items = []
for index, row in cleaned_rules_switz.iterrows():
    all_items.extend(row['antecedents'])
    all_items.extend(row['consequents'])

# Count the occurrence of each item
from collections import Counter
item_counts = Counter(all_items)

# Get the maximum occurring item
max_item = max(item_counts, key=item_counts.get)

# Print the maximum occurring item and its count
print(f"The maximum occurring item is '{max_item}' with a count of {item_counts[max_item]}")
# Out:
# The maximum occurring item is '['ROUND SNACK BOXES SET OF4 WOODLAND ']' with a count of 101

# %%
# The number of rules
cleaned_rules_switz.shape[0]
# Out:
# 184

# %%
high_confidance_switz = cleaned_rules_switz[rules_switz['confidence'] > 0.75]
high_confidance_switz [['antecedents', 'consequents']]
# Out:
# <ipython-input-419-e18d3896af32>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_confidance_switz = cleaned_rules_switz[rules_switz['confidence'] > 0.75]
#                                            antecedents  \
# 0                        ([' SPACEBOY BABY GIFT SET'])
# 1                             (['RED RETROSPOT BOWL'])
# 3                             (['CARD CIRCUS PARADE'])
# 4    (['CHILDRENS CUTLERY SPACEBOY ' 'KIDS CUTLERY ...
# 6               (['RED RETROSPOT CHILDRENS UMBRELLA'])
# ..                                                 ...
# 178  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['WA...
# 179  (['ROUND SNACK BOXES SET OF4 WOODLAND '], ['WA...
# 180  (['WATERING CAN PINK BUNNY'], ['WATERING CAN B...
# 181                (['RED TOADSTOOL LED NIGHT LIGHT'])
# 183                   (['WATERING CAN BLUE ELEPHANT'])
#
#                                            consequents
# 0               (['PLASTERS IN TIN WOODLAND ANIMALS'])
# ...

# %% [markdown]
# 9th Country - Portugal

# %%
# Build the Apriori model
rep_items_port = apriori(df_itms_togthr_port, min_support = 0.1, use_colnames = True)
rep_items_port
# Out:
#       support                                           itemsets
# 0    0.142857                  (['4 TRADITIONAL SPINNING TOPS'])
# 1    0.102041                  (['60 TEATIME FAIRY CAKE CASES'])
# 2    0.244898                (['BAKING SET 9 PIECE RETROSPOT '])
# 3    0.102041                       (['BLUE HARMONICA IN BOX '])
# 4    0.102041                (['BOX OF VINTAGE JIGSAW BLOCKS '])
# ..        ...                                                ...
# 331  0.102041  (['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG DOIL...
# 332  0.102041  (['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG CARS...
# 333  0.102041  (['LUNCH BAG CARS BLUE'], ['JUMBO BAG SCANDINA...
# 334  0.102041  (['LUNCH BAG CARS BLUE'], ['JUMBO BAG SCANDINA...
# 335  0.102041  (['LUNCH BAG CARS BLUE'], ['JUMBO BAG SCANDINA...
#
# [336 rows x 2 columns]

# %%
# Generate the association rules dataframe
rules_port = association_rules(rep_items_port, metric = "confidence", min_threshold = 0.6)
rules_port
# Out:
#                                             antecedents  \
# 0                     (['4 TRADITIONAL SPINNING TOPS'])
# 1                     (['4 TRADITIONAL SPINNING TOPS'])
# 2                   (['BAKING SET 9 PIECE RETROSPOT '])
# 3                (['RETROSPOT TEA SET CERAMIC 11 PC '])
# 4                     (['CHARLOTTE BAG PINK POLKADOT'])
# ...                                                 ...
# 2148  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 2149  (['JUMBO BAG PINK VINTAGE PAISLEY'], ['LUNCH B...
# 2150  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 2151  (['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPO...
# 2152  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
#
#                                             consequents  antecedent support  \
# 0                       (['CHARLOTTE BAG SUKI DESIGN'])            0.142857
# 1                (['RETROSPOT TEA SET CERAMIC 11 PC '])            0.142857
# ...

# %%
# Generate the association rules dataframe
rules_port = association_rules(rep_items_port, metric="confidence", min_threshold=0.6)

# Create a copy of the rules dataframe
cleaned_rules_port = rules_port.copy()

# Loop through each rule
for i, rule_port in rules_port.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules_port['antecedents'].isin([rule_port['consequents']]) & cleaned_rules_port['consequents'].isin([rule_port['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules_port = cleaned_rules_port.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules_port = cleaned_rules_port.reset_index(drop=True)

# Print the cleaned rules dataframe
print(cleaned_rules_port)
# Out:
#                                             antecedents  \
# 0                     (['4 TRADITIONAL SPINNING TOPS'])
# 1                     (['4 TRADITIONAL SPINNING TOPS'])
# 2                (['RETROSPOT TEA SET CERAMIC 11 PC '])
# 3                     (['CHARLOTTE BAG PINK POLKADOT'])
# 4                       (['CHARLOTTE BAG SUKI DESIGN'])
# ...                                                 ...
# 1387  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 1388  (['JUMBO BAG PINK VINTAGE PAISLEY'], ['LUNCH B...
# 1389  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 1390  (['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPO...
# 1391  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
#
#                                             consequents  antecedent support  \
# 0                       (['CHARLOTTE BAG SUKI DESIGN'])            0.142857
# 1                (['RETROSPOT TEA SET CERAMIC 11 PC '])            0.142857
# ...

# %%
cleaned_rules_port = pd.DataFrame(data=cleaned_rules_port)
cleaned_rules_port
# Out:
#                                             antecedents  \
# 0                     (['4 TRADITIONAL SPINNING TOPS'])
# 1                     (['4 TRADITIONAL SPINNING TOPS'])
# 2                (['RETROSPOT TEA SET CERAMIC 11 PC '])
# 3                     (['CHARLOTTE BAG PINK POLKADOT'])
# 4                       (['CHARLOTTE BAG SUKI DESIGN'])
# ...                                                 ...
# 1387  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 1388  (['JUMBO BAG PINK VINTAGE PAISLEY'], ['LUNCH B...
# 1389  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 1390  (['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPO...
# 1391  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
#
#                                             consequents  antecedent support  \
# 0                       (['CHARLOTTE BAG SUKI DESIGN'])            0.142857
# 1                (['RETROSPOT TEA SET CERAMIC 11 PC '])            0.142857
# ...

# %%
# Concatenate all the antecedents and consequents
all_items = []
for index, row in cleaned_rules_port.iterrows():
    all_items.extend(row['antecedents'])
    all_items.extend(row['consequents'])

# Count the occurrence of each item
from collections import Counter
item_counts = Counter(all_items)

# Get the maximum occurring item
max_item = max(item_counts, key=item_counts.get)

# Print the maximum occurring item and its count
print(f"The maximum occurring item is '{max_item}' with a count of {item_counts[max_item]}")
# Out:
# The maximum occurring item is '['JUMBO SHOPPER VINTAGE RED PAISLEY']' with a count of 914

# %%
# The number of rules
cleaned_rules_port.shape[0]
# Out:
# 1392

# %%
high_confidance_port = cleaned_rules_port[rules_port['confidence'] > 0.75]
high_confidance_port [['antecedents', 'consequents']]
# Out:
# <ipython-input-426-2c016f3b6d7c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_confidance_port = cleaned_rules_port[rules_port['confidence'] > 0.75]
#                                             antecedents  \
# 2                (['RETROSPOT TEA SET CERAMIC 11 PC '])
# 4                       (['CHARLOTTE BAG SUKI DESIGN'])
# 10    (['JUMBO BAG DOILEY PATTERNS' 'JUMBO BAG VINTA...
# 14    (['JUMBO BAG SCANDINAVIAN PAISLEY' 'JUMBO BAG ...
# 18                 (['JUMBO BAG PINK VINTAGE PAISLEY'])
# ...                                                 ...
# 1385  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
# 1386  (['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPO...
# 1388  (['JUMBO BAG PINK VINTAGE PAISLEY'], ['LUNCH B...
# 1390  (['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPO...
# 1391  (['LUNCH BAG SUKI  DESIGN ' 'LUNCH BAG SUKI DE...
#
#                                             consequents
# ...

# %% [markdown]
# 10th Country - Australia

# %%
# Build the Apriori model
rep_items_aust = apriori(df_itms_togthr_aust, min_support = 0.1, use_colnames = True)
rep_items_aust
# Out:
#      support                                           itemsets
# 0   0.107143                   (['ALARM CLOCK BAKELIKE GREEN'])
# 1   0.107143                    (['ALARM CLOCK BAKELIKE RED '])
# 2   0.125000                (['BAKING SET 9 PIECE RETROSPOT '])
# 3   0.142857                   (['BAKING SET SPACEBOY DESIGN'])
# 4   0.107143  (['DOILEY STORAGE TIN' 'DOILEY BISCUIT TIN' 'S...
# 5   0.107143                         (['DOLLY GIRL LUNCH BOX'])
# 6   0.107143                           (['DOORMAT UNION FLAG'])
# 7   0.125000             (['HANGING HEART JAR T-LIGHT HOLDER'])
# 8   0.107143                     (['JAM MAKING SET WITH JARS'])
# 9   0.107143                       (['LUNCH BAG APPLE DESIGN'])
# 10  0.142857  (['LUNCH BAG RED RETROSPOT' 'LUNCH BAG RED SPO...
# 11  0.142857                   (['LUNCH BAG SPACEBOY DESIGN '])
# 12  0.107143                           (['LUNCH BAG WOODLAND'])
# 13  0.107143                      (['MINI PAINT SET VINTAGE '])
# ...

# %%
# Generate the association rules dataframe
rules_aust = association_rules(rep_items_aust, metric = "confidence", min_threshold = 0.6)
rules_aust
# Out:
#                         antecedents                       consequents  \
# 0  (['ALARM CLOCK BAKELIKE GREEN'])   (['ALARM CLOCK BAKELIKE RED '])
# 1   (['ALARM CLOCK BAKELIKE RED '])  (['ALARM CLOCK BAKELIKE GREEN'])
# 2         (['SPACEBOY LUNCH BOX '])        (['DOLLY GIRL LUNCH BOX'])
# 3        (['DOLLY GIRL LUNCH BOX'])         (['SPACEBOY LUNCH BOX '])
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.107143            0.107143  0.107143         1.0  9.333333
# 1            0.107143            0.107143  0.107143         1.0  9.333333
# 2            0.107143            0.107143  0.107143         1.0  9.333333
# 3            0.107143            0.107143  0.107143         1.0  9.333333
#
#    leverage  conviction
# 0  0.095663         inf
# 1  0.095663         inf
# 2  0.095663         inf
# 3  0.095663         inf

# %%
# Generate the association rules dataframe
rules_aust = association_rules(rep_items_aust, metric="confidence", min_threshold=0.6)

# Create a copy of the rules dataframe
cleaned_rules_aust = rules_aust.copy()

# Loop through each rule
for i, rule_aust in rules_aust.iterrows():
    # Check if the reversed rule already exists in the dataframe
    if (cleaned_rules_aust['antecedents'].isin([rule_aust['consequents']]) & cleaned_rules_aust['consequents'].isin([rule_aust['antecedents']])).any():
        # If it exists, drop the duplicate rule
        cleaned_rules_aust = cleaned_rules_aust.drop(i)

# Reset the index of the cleaned rules dataframe
cleaned_rules_aust = cleaned_rules_aust.reset_index(drop=True)

# Print the cleaned rules dataframe
print(cleaned_rules_aust)
# Out:
#                        antecedents                       consequents  \
# 0  (['ALARM CLOCK BAKELIKE RED '])  (['ALARM CLOCK BAKELIKE GREEN'])
# 1       (['DOLLY GIRL LUNCH BOX'])         (['SPACEBOY LUNCH BOX '])
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.107143            0.107143  0.107143         1.0  9.333333
# 1            0.107143            0.107143  0.107143         1.0  9.333333
#
#    leverage  conviction
# 0  0.095663         inf
# 1  0.095663         inf

# %%
cleaned_rules_aust = pd.DataFrame(data=cleaned_rules_aust)
cleaned_rules_aust
# Out:
#                        antecedents                       consequents  \
# 0  (['ALARM CLOCK BAKELIKE RED '])  (['ALARM CLOCK BAKELIKE GREEN'])
# 1       (['DOLLY GIRL LUNCH BOX'])         (['SPACEBOY LUNCH BOX '])
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.107143            0.107143  0.107143         1.0  9.333333
# 1            0.107143            0.107143  0.107143         1.0  9.333333
#
#    leverage  conviction
# 0  0.095663         inf
# 1  0.095663         inf

# %%
# The number of rules
cleaned_rules_aust.shape[0]
# Out:
# 2

# %%
high_confidance_aust = cleaned_rules_aust[rules_aust['confidence'] > 0.75]
high_confidance_aust [['antecedents', 'consequents']]
# Out:
# <ipython-input-432-ba8bbf792714>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_confidance_aust = cleaned_rules_aust[rules_aust['confidence'] > 0.75]
#                        antecedents                       consequents
# 0  (['ALARM CLOCK BAKELIKE RED '])  (['ALARM CLOCK BAKELIKE GREEN'])
# 1       (['DOLLY GIRL LUNCH BOX'])         (['SPACEBOY LUNCH BOX '])

# %% [markdown]
# COMPARING THE TOP 10 COUNTRIES
#
#
# The Association rules and confidence was generated in (Descending Order):
#
# 1. Portugal
# 2. Switzerland
# 3. Netherlands
# 4. Belgium
# 5. France
# 6. EIRE
# 7. Australia
# 8. Germany
# 9. Spain
# 10. United Kingdom

# %% [markdown]
# Sometimes the number of frequent itemsets maybe less than the association rules generated for that particular region
